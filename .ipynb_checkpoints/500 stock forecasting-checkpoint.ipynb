# %% [markdown]
# # Time-Series Forecasting: Prédictions récursives des valeurs du SP500 sur 100 jours

# %% [markdown]
# Attention : l'exécution de ce notebook prend plusieurs heures même avec un bon processeur et carte graphique, merci de vous armer de patience si vous souhaitez exécuter ce notebook, environ 80GB de RAM/VRAM sont également recommandé. L'utilisation de carte graphique récente dédiée (voir spécialisé type Nvidia A100) est fortement recommandé

# %%
import os
import numpy as np
import pandas as pd
import yfinance as yf
import tensorflow as tf
from sklearn.preprocessing import RobustScaler, MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, GRU, Input, Add, Conv1D, MultiHeadAttention, Dropout, Bidirectional
from tensorflow.keras.models import Model 
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor
from patsy import dmatrices
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import xgboost as xgb
from itertools import product
from keras.callbacks import EarlyStopping
import torch
from torch.optim import Adam
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
from sklearn.model_selection import TimeSeriesSplit
from statsmodels.tsa.stattools import acf, pacf
from math import sqrt
from skopt import gp_minimize
from skopt.space import Integer
import optuna
import plotly
from tensorflow.keras.layers import Attention
from sklearn.model_selection import TimeSeriesSplit
from keras.regularizers import l1, l2, l1_l2
from datetime import datetime, timedelta
import warnings
from statsmodels.tools.sm_exceptions import ConvergenceWarning
from scipy.ndimage import gaussian_filter1d
from scipy.stats import kurtosis, skew
from keras import backend as K
from sklearn.metrics import confusion_matrix

# %%
print(tf.config.experimental.list_physical_devices('GPU'))
print(torch.cuda.is_available())
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    # Utiliser le premier GPU
    tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# True

# %%
# Calculer la date d'hier
yesterday = datetime.now() - timedelta(1)
yesterday_str = yesterday.strftime('%Y-%m-%d')
# import the data
GSPC_data= yf.download('^GSPC',start='2001-06-25',end=yesterday_str)
VIX_data = yf.download('^VIX', start='2001-06-25', end=yesterday_str)
CL_DF_data = yf.download('CL=F', start='2001-06-25', end=yesterday_str)
GC_F_data = yf.download('GC=F', start='2001-06-25', end=yesterday_str)
EURUSD_X_data = yf.download('EURUSD=X', start='2001-06-25', end=yesterday_str)
GBPUSD_X_data = yf.download('GBPUSD=X', start='2001-06-25', end=yesterday_str)
JPY_X_data = yf.download('JPY=X', start='2001-06-25', end=yesterday_str)
RUB_X_data = yf.download('RUB=X', start='2001-06-25', end=yesterday_str)
NG_F_data = yf.download('NG=F', start='2001-06-25', end=yesterday_str)
TNX_data = yf.download('^TNX', start='2001-06-25', end=yesterday_str)
FVX_data = yf.download('^FVX', start='2001-06-25', end=yesterday_str)
FCHI_data = yf.download('^FCHI', start='2001-06-25', end=yesterday_str)
DJI_data = yf.download('^DJI', start='2001-06-25', end=yesterday_str)
JPM_data = yf.download('JPM', start='2001-06-25', end=yesterday_str)
CNY_X_data = yf.download('CNY=X', start='2001-06-25', end=yesterday_str)
SZ_data = yf.download('399001.SZ', start='2001-06-25', end=yesterday_str)
SS_data = yf.download('000001.SS', start='2001-06-25', end=yesterday_str)
MXX_data = yf.download('^MXX', start='2001-06-25', end=yesterday_str)
BVSP_data = yf.download('^BVSP', start='2001-06-25', end=yesterday_str)
N225_data = yf.download('^N225', start='2001-06-25', end=yesterday_str)
HSI_data = yf.download('^HSI', start='2001-06-25', end=yesterday_str)
STI_data = yf.download('^STI', start='2001-06-25', end=yesterday_str)
BSESN_data = yf.download('^BSESN', start='2001-06-25', end=yesterday_str)
TSM_data = yf.download('TSM', start='2001-06-25', end=yesterday_str) 
ORAPA_data = yf.download('ORA.PA', start='2001-06-25', end=yesterday_str)
VZ_data = yf.download('VZ', start='2001-06-25', end=yesterday_str)
VODL_data = yf.download('VOD.L', start='2001-06-25', end=yesterday_str) 
ADBE_data = yf.download('ADBE', start='2001-06-25', end=yesterday_str)
AAPL_data = yf.download('AAPL', start='2001-06-25', end=yesterday_str)
MSFT_data = yf.download('MSFT', start='2001-06-25', end=yesterday_str)
ORCL_data = yf.download('ORCL', start='2001-06-25', end=yesterday_str)
IBM_data = yf.download('IBM', start='2001-06-25', end=yesterday_str)
INTC_data = yf.download('INTC', start='2001-06-25', end=yesterday_str)
QCOM_data = yf.download('QCOM', start='2001-06-25', end=yesterday_str)
NVDA_data = yf.download('NVDA', start='2001-06-25', end=yesterday_str)
AMZN_data = yf.download('AMZN', start='2001-06-25', end=yesterday_str)
TXN_data = yf.download('TXN', start='2001-06-25', end=yesterday_str)
CVX_data = yf.download('CVX', start='2001-06-25', end=yesterday_str) 
AIPA_data = yf.download('AI.PA', start='2001-06-25', end=yesterday_str)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
GSPC_data.shape
# Out:
# (5613, 6)

# %%
#lets look at the stock closing price of history
plt.figure(figsize=(20,10))
sns.lineplot(x= GSPC_data.index,y=GSPC_data['Close'])
plt.xlabel('Date', fontsize=20)
plt.ylabel('closing price USD ($)',fontsize=20)
plt.title('Closing price History',fontsize=25)
# Out:
# Text(0.5, 1.0, 'Closing price History')

# %%
# Liste de vos DataFrames et leurs noms
dataframes = [GSPC_data, VIX_data, CL_DF_data, GC_F_data, EURUSD_X_data, GBPUSD_X_data, JPY_X_data, RUB_X_data, NG_F_data, TNX_data, FVX_data, FCHI_data, DJI_data, CNY_X_data, SZ_data, SS_data, MXX_data, BVSP_data, N225_data, HSI_data, STI_data, BSESN_data, TSM_data, ORAPA_data, VZ_data, VODL_data, ADBE_data, AAPL_data, MSFT_data, ORCL_data, IBM_data, INTC_data, QCOM_data, NVDA_data, AMZN_data, TXN_data, CVX_data, AIPA_data]
names = ['GSPC', 'VIX', 'CL_DF', 'GC_F', 'EURUSD_X', 'GBPUSD_X', 'JPY_X', 'RUB_X', 'NG_F', 'TNX', 'FVX', 'FCHI', 'DJI', 'CNY_X', 'SZ', 'SS', 'MXX', 'BVSP', 'N225', 'HSI', 'STI', 'BSESN', 'TSM', 'ORAPA', 'VZ', 'VODL', 'ADBE', 'AAPL', 'MSFT', 'ORCL', 'IBM', 'INTC', 'QCOM', 'NVDA', 'AMZN', 'TXN', 'CVX', 'AIPA']

# Initialiser un DataFrame vide
combined_data = pd.DataFrame()

# Parcourir chaque DataFrame et ajouter ses colonnes au DataFrame combiné
for df, name in zip(dataframes, names):
    # Sélectionnez seulement les colonnes qui vous intéressent (Open, Close, Min, Max)
    selected_columns = df[['Open', 'Close', 'Low', 'High']]
    
    # Renommez les colonnes pour inclure le nom de l'indice
    selected_columns.columns = pd.MultiIndex.from_product([[name], ['Open', 'Close', 'Low', 'High']])
    
    # Concaténez les colonnes sélectionnées au DataFrame combiné
    if combined_data.empty:
        combined_data = selected_columns
    else:
        combined_data = pd.concat([combined_data, selected_columns], axis=1)

combined_data.dropna(inplace=True)
# Affichez les premières lignes du DataFrame combiné
print(combined_data.shape)
# Out:
# (3680, 152)

# %% [markdown]
# ### Carte de chaleur de correlation entre les features du modèle:

# %%
# Calculate the correlation matrix
correlation_matrix = combined_data.corr()

# %% [markdown]
# ### Sélection des features

# %%
# Sélectionner les caractéristiques avec une forte corrélation
target = ('GSPC', 'Close')
correlation_threshold = 0.8

# Trouver les caractéristiques fortement corrélées
highly_correlated_features = [idx for idx, corr in correlation_matrix[target].items() if abs(corr) > correlation_threshold]

print(f"Selected indices: {highly_correlated_features}")
# Out:
# Selected indices: [('GSPC', 'Open'), ('GSPC', 'Close'), ('GSPC', 'Low'), ('GSPC', 'High'), ('RUB_X', 'Open'), ('RUB_X', 'Close'), ('RUB_X', 'Low'), ('RUB_X', 'High'), ('FCHI', 'Open'), ('FCHI', 'Close'), ('FCHI', 'Low'), ('FCHI', 'High'), ('DJI', 'Open'), ('DJI', 'Close'), ('DJI', 'Low'), ('DJI', 'High'), ('BVSP', 'Open'), ('BVSP', 'Close'), ('BVSP', 'Low'), ('BVSP', 'High'), ('N225', 'Open'), ('N225', 'Close'), ('N225', 'Low'), ('N225', 'High'), ('BSESN', 'Open'), ('BSESN', 'Close'), ('BSESN', 'Low'), ('BSESN', 'High'), ('TSM', 'Open'), ('TSM', 'Close'), ('TSM', 'Low'), ('TSM', 'High'), ('ADBE', 'Open'), ('ADBE', 'Close'), ('ADBE', 'Low'), ('ADBE', 'High'), ('AAPL', 'Open'), ('AAPL', 'Close'), ('AAPL', 'Low'), ('AAPL', 'High'), ('MSFT', 'Open'), ('MSFT', 'Close'), ('MSFT', 'Low'), ('MSFT', 'High'), ('ORCL', 'Open'), ('ORCL', 'Close'), ('ORCL', 'Low'), ('ORCL', 'High'), ('QCOM', 'Open'), ('QCOM', 'Close'), ('QCOM', 'Low'), ('QCOM', 'High'), ('NVDA', 'Open'), ('NVDA', 'Close'), ('NVDA', 'Low'), ('NVDA', 'High'), ('AMZN', 'Open'), ('AMZN', 'Close'), ('AMZN', 'Low'), ('AMZN', 'High'), ('TXN', 'Open'), ('TXN', 'Close'), ('TXN', 'Low'), ('TXN', 'High'), ('AIPA', 'Open'), ('AIPA', 'Close'), ('AIPA', 'Low'), ('AIPA', 'High')]

# %% [markdown]
# ### Gestion de la Multicollinéarité

# %%
# Afficher la heatmap
selected_correlation_matrix = combined_data[highly_correlated_features].corr()

plt.figure(figsize=(40, 20))
sns.heatmap(selected_correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Calculate VIF
def calculate_vif(dataframe, threshold=4.0):
    vif = pd.DataFrame()
    vif["Variable"] = [str(col) for col in dataframe.columns]
    vif["VIF"] = [variance_inflation_factor(dataframe.values, i) for i in range(dataframe.shape[1])]
    
    while vif["VIF"].max() > threshold:
        remove = vif.sort_values("VIF", ascending=False).iloc[0]
        removed_var = dataframe.columns[int(remove.name)]
        dataframe = dataframe.drop(removed_var, axis=1)
        vif = pd.DataFrame()
        vif["Variable"] = [str(col) for col in dataframe.columns]
        vif["VIF"] = [variance_inflation_factor(dataframe.values, i) for i in range(dataframe.shape[1])]

    return dataframe

# %% [markdown]
# ### Sélection des features définitives:

# %%
#highly_correlated_features.remove(target)
filtred_df = combined_data[highly_correlated_features].copy()
last_two_years_data = combined_data.last('2Y')

close_values_last_two_years = last_two_years_data.xs('Close', level=1, axis=1)
reduced_df = calculate_vif(close_values_last_two_years)

# Conserver seulement les indices qui ne sont pas colinéaires
valid_indices = reduced_df.columns.tolist()

# Créer un nouveau DataFrame contenant toutes les variables pour ces indices
final_df = combined_data.loc[:, pd.IndexSlice[valid_indices, :]]
print(final_df.shape)
# Out:
# (3680, 8)

# %% [markdown]
# ### Normalisation des données

# %%
# Initialisez un dictionnaire pour stocker les scalers
scalers_dict = {}

# Créez un DataFrame vide pour stocker les données mises à l'échelle
scaled_data_df = pd.DataFrame(index=final_df.index)

# Itérer sur le premier niveau de l'index multi-niveaux (noms des indices)
for first_level in final_df.columns.levels[0]:
    # Itérer sur le second niveau de l'index multi-niveaux (Open, Close, High, Low)
    for second_level in final_df.columns.levels[1]:
        feature = (first_level, second_level)
        
        if feature in final_df.columns:
            feature_scaler = RobustScaler()
            scaled_feature = feature_scaler.fit_transform(final_df[feature].values.reshape(-1, 1))
            scaled_data_df[feature] = scaled_feature.flatten()  # Convertir les données 2D en 1D
            
            # Stocker le scaler pour chaque combinaison d'indice et de mesure
            scalers_dict[feature] = feature_scaler

print(scaled_data_df.tail())
# Out:
#             (NG_F, Close)  (NG_F, High)  (NG_F, Low)  (NG_F, Open)  \
# Date
# 2023-09-27      -0.346793     -0.357172    -0.378289     -0.387005
# 2023-09-28      -0.285762     -0.292084    -0.298833     -0.308093
# 2023-10-10      -0.138414     -0.139777    -0.135738     -0.146911
# 2023-10-11      -0.140099     -0.138150    -0.174421     -0.135494
# 2023-10-13      -0.187642     -0.172647    -0.182087     -0.155306
#
#             (NVDA, Close)  (NVDA, High)  (NVDA, Low)  (NVDA, Open)
# Date
# 2023-09-27       8.851741      8.781015     8.901788      8.869772
# 2023-09-28       8.982835      8.900110     9.007053      8.897364
# 2023-10-10       9.554708      9.483758     9.650986      9.502275
# 2023-10-11       9.767498      9.608247     9.859349      9.690328
# 2023-10-13       9.483567      9.661570     9.692572      9.852487

# %%
# Split into train and test:
# Définissez la taille de l'ensemble d'entraînement
train_size = int(len(scaled_data_df)) - 250
test_size = 250

# Séparez les données
train_data = scaled_data_df.iloc[:train_size]
test_data = scaled_data_df.iloc[train_size:]
print(train_data.shape)
print(test_data.shape)
# Out:
# (3430, 8)
# (250, 8)

# %%
train_data.to_csv('train_data.csv')
test_data.to_csv('test_data.csv')

# %% [markdown]
# ### Création d'une métrique personalisée pour la prédiction récursive

# %%
def weighted_rmse(y_true, y_pred, total_observations):
    weights = np.arange(total_observations, 0, -1) / total_observations
    weighted_square_errors = weights * ((y_pred - y_true) ** 2)
    weighted_rmse = sqrt(np.mean(weighted_square_errors))
    return weighted_rmse
    
    weighted_square_errors = weights * ((y_pred - y_true) ** 2)
    weighted_rmse = sqrt(np.mean(weighted_square_errors))
    return weighted_rmse

# %% [markdown]
# # Recherche de la meilleure architecture pour les modèles neuronaux

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True)
best_params_per_feature = {}
top_n_trials_per_feature = {}

# Function to create sequences for multi-output prediction

def create_single_output_sequences(data, index_name, look_back=1):
    X, y = [], []
    feature_columns = ['Close']
    for i in range(look_back, len(data)):
        sequence_data = data.loc[data.index[i-look_back:i], [(index_name, col) for col in feature_columns]].values
        X.append(sequence_data)
        y.append(data.loc[data.index[i], [(index_name, 'Close')]].values[0])
    return np.array(X), np.array(y)

def generate_recursive_predictions(model, X_val, n_steps=10):
    # Supposons que X_val soit de forme (nombre_d'exemples, look_back, nombre_de_features)
    recursive_predictions = []
    input_sequence = X_val[0].reshape(1, X_val.shape[1], X_val.shape[2])  # Prendre la première séquence

    for i in range(n_steps):
        # Faire une prédiction à partir de la séquence d'entrée
        prediction = model.predict(input_sequence, verbose=0)
        recursive_predictions.append(prediction[0, 0])

        # Mettre à jour la séquence d'entrée pour inclure la nouvelle prédiction
        new_input_sequence = np.append(input_sequence[0, 1:, :], prediction)
        input_sequence = new_input_sequence.reshape(1, X_val.shape[1], X_val.shape[2])

    return np.array(recursive_predictions)


def create_model(num_layers, layer_type, units_per_layer, dropout_per_layer, input_shape, use_conv1d , conv1d_filters ,conv1d_kernel_size ,use_residual_connection, attention_layer, l1_reg, l2_reg):
    inputs = Input(shape=input_shape)
    x = inputs
    if use_conv1d:
        x = Conv1D(conv1d_filters, kernel_size=conv1d_kernel_size, activation='relu')(x)
    if layer_type[0] == "GRU":
        x = Bidirectional(GRU(units_per_layer[0], return_sequences=True, kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg)))(x)
    elif layer_type[0] == "LSTM":
        x = Bidirectional(LSTM(units_per_layer[0], return_sequences=True, kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg)))(x)
    x = Dropout(dropout_per_layer[0])(x)
    for i in range(1, num_layers):
        if use_residual_connection and units_per_layer[i] == units_per_layer[i-1]:
            x_res = x
        if layer_type[i] == "GRU":
            x = Bidirectional(GRU(units_per_layer[i], return_sequences=True, kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg)))(x)
        elif layer_type[i] == "LSTM":
            x = Bidirectional(LSTM(units_per_layer[i], return_sequences=True, kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg)))(x)
        x = Dropout(dropout_per_layer[i])(x)
        if attention_layer:
            x = Attention(use_scale=True)([x, x])
        if use_residual_connection and units_per_layer[i] == units_per_layer[i-1]:
            x = Add()([x, x_res])
    if layer_type[num_layers-1] == "GRU":
        x = Bidirectional(GRU(units_per_layer[num_layers-1]))(x)
    elif layer_type[num_layers-1] == "LSTM":
        x = Bidirectional(LSTM(units_per_layer[num_layers-1]))(x)
    x = Dense(25)(x)
    outputs = Dense(1)(x)
    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

for index_name in final_df.columns.get_level_values(0).unique():  # Parcourir chaque indice

    # Définition de l'objectif
    def objective(trial):

        # Espace de recherche
        ###############################################################################################
        look_back = trial.suggest_int('look_back', int(test_size/4), int(test_size/2) - 1)
        num_layers = trial.suggest_int('num_layers', 5, 8)
        layer_type = [trial.suggest_categorical(f'layer_type_{i}', ['LSTM', 'GRU']) for i in range(num_layers)]
        units_per_layer = [trial.suggest_int(f'units_power_{i}', 7, 9) for i in range(num_layers)]
        units_per_layer = [2 ** power for power in units_per_layer]
        dropout_per_layer = [trial.suggest_float(f'dropout_{i}', 0.1, 0.3) for i in range(num_layers)]
        use_residual_connection = trial.suggest_categorical('use_residual_connection', [True, False])
        attention_layer = trial.suggest_categorical('use_attention_layer', [True, False])
        use_conv1d = trial.suggest_categorical('use_conv1d', [False, True])
        if use_conv1d:
            conv1d_filters = trial.suggest_int('conv1d_filters', 5, 7)
            conv1d_filters = 2 ** conv1d_filters
            conv1d_kernel_size = trial.suggest_int('conv1d_kernel_size', 3, 7)
        l1_reg = trial.suggest_float('l1_reg', 1e-5, 1e-1, log=True)
        l2_reg = trial.suggest_float('l2_reg', 1e-5, 1e-1, log=True)
        ################################################################################################

        # Créez des séquences en utilisant look_back
        X_train, y_train = create_single_output_sequences(train_data, index_name , look_back)
        X_test, y_test = create_single_output_sequences(test_data, index_name ,look_back)

        n_splits = 5  # Nombre de splits
        tscv = TimeSeriesSplit(n_splits=n_splits)

        val_loss_list = []  # Liste pour stocker la val_loss de chaque split
        mda_list = []  # Liste pour stocker MDA de chaque split
        train_loss_list = []  # Liste pour stocker la loss de chaque split

        for train_index, val_index in tscv.split(X_train):
            X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
            y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

            if use_conv1d:
                model = create_model(num_layers, layer_type, units_per_layer, dropout_per_layer, ((look_back), 1), use_conv1d, conv1d_filters, conv1d_kernel_size, use_residual_connection, attention_layer, l1_reg, l2_reg)
            else:
                conv1d_filters = 36
                conv1d_kernel_size = 5
                model = create_model(num_layers, layer_type, units_per_layer, dropout_per_layer, ((look_back), 1), use_conv1d, conv1d_filters, conv1d_kernel_size, use_residual_connection, attention_layer, l1_reg, l2_reg)

            history = model.fit(X_train_fold, y_train_fold, validation_data=(X_val_fold, y_val_fold), epochs=10, batch_size=64, verbose=0, callbacks=[early_stopping])

            last_val_loss = history.history['val_loss'][-1]
            last_train_loss = history.history['loss'][-1]
            
            # Calcul de MDA
            y_true_direction = np.sign(np.diff(y_val_fold.reshape(-1)))  # vrai direction
            y_pred_direction = np.sign(np.diff(model.predict(X_val_fold, verbose=0).reshape(-1)))  # prédiction de direction
            mda = np.mean(y_true_direction == y_pred_direction)
            
            val_loss_list.append(last_val_loss)
            train_loss_list.append(last_train_loss)
            mda_list.append(mda)
        
        mean_val_loss = np.mean(val_loss_list)
        mean_train_loss = np.mean(train_loss_list)
        mean_mda = np.mean(mda_list)
        
        
        # Calcul des malus
        loss_difference_malus = abs(mean_val_loss - mean_train_loss) * 1
        recursive_predictions = generate_recursive_predictions(model, X_val_fold, len(X_val_fold))
        std_value = np.std(recursive_predictions)  # Calcul de l'écart-type des prédictions récursives
        if std_value == 0:
            std_malus = 3  # Si l'écart-type est de 0, pénalité maximale
        else:
            std_malus = 1 - std_value

        # Calcul du score final avec les malus
        final_score = (1 - mean_mda) + loss_difference_malus + std_malus

        print("mda: " + str(mean_mda))
        print("loss diff: " + str(loss_difference_malus))
        print("std: " + str(std_malus))

        return final_score

    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=35)
    
    best_params_per_feature[index_name] = study.best_params

    top_n_trials = sorted(study.trials, key=lambda trial: trial.value)[:5]

    # Stockez les meilleurs hyperparamètres
    top_n_params = [trial.params for trial in top_n_trials]

    # Stockez ces meilleurs paramètres dans le dictionnaire
    top_n_trials_per_feature[index_name] = top_n_params

    # Affichage des résultats
    print(f'Number of finished trials for {index_name}: ', len(study.trials))
    print('Best 5 trials:')
    for i, trial in enumerate(top_n_trials):
        print(f'Rank {i+1} - Value: {trial.value}, Params: {trial.params}')
# Out:
# [I 2023-10-18 13:49:00,173] A new study created in memory with name: no-name-900bab2b-20c8-4eda-a64a-1c3ec532e6a4
# [I 2023-10-18 13:58:38,912] Trial 0 finished with value: 4.560661986131698 and parameters: {'look_back': 119, 'num_layers': 7, 'layer_type_0': 'LSTM', 'layer_type_1': 'GRU', 'layer_type_2': 'GRU', 'layer_type_3': 'LSTM', 'layer_type_4': 'LSTM', 'layer_type_5': 'LSTM', 'layer_type_6': 'LSTM', 'units_power_0': 8, 'units_power_1': 7, 'units_power_2': 9, 'units_power_3': 7, 'units_power_4': 8, 'units_power_5': 8, 'units_power_6': 9, 'dropout_0': 0.19938829775404215, 'dropout_1': 0.13420979974967034, 'dropout_2': 0.1034758286498848, 'dropout_3': 0.14033173162088095, 'dropout_4': 0.21895085350685373, 'dropout_5': 0.29522719553757837, 'dropout_6': 0.14282894092334503, 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': False, 'l1_reg': 0.06342927941589098, 'l2_reg': 0.0006288996546124074}. Best is trial 0 with value: 4.560661986131698.
# mda: 0.2727272727272727
# loss diff: 2.8333892822265625
# std: 0.9999999766324077
# [I 2023-10-18 14:09:04,705] Trial 1 finished with value: 1.6348001791408115 and parameters: {'look_back': 122, 'num_layers': 8, 'layer_type_0': 'GRU', 'layer_type_1': 'GRU', 'layer_type_2': 'GRU', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'LSTM', 'layer_type_6': 'GRU', 'layer_type_7': 'LSTM', 'units_power_0': 8, 'units_power_1': 7, 'units_power_2': 8, 'units_power_3': 8, 'units_power_4': 9, 'units_power_5': 9, 'units_power_6': 7, 'units_power_7': 8, 'dropout_0': 0.18657962164003822, 'dropout_1': 0.12460816923588525, 'dropout_2': 0.13442110564233745, 'dropout_3': 0.16950469452006206, 'dropout_4': 0.16182246061147015, 'dropout_5': 0.17118371085884102, 'dropout_6': 0.18202208840552975, 'dropout_7': 0.21515459460786807, 'use_residual_connection': False, 'use_attention_layer': False, 'use_conv1d': False, 'l1_reg': 8.56818871025975e-05, 'l2_reg': 0.0004952638003360324}. Best is trial 1 with value: 1.6348001791408115.
# mda: 0.48981818181818176
# loss diff: 0.13550560474395734
# std: 0.9891127562150359
# [I 2023-10-18 14:15:54,000] Trial 2 finished with value: 0.010382176280021471 and parameters: {'look_back': 120, 'num_layers': 5, 'layer_type_0': 'LSTM', 'layer_type_1': 'LSTM', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'units_power_0': 7, 'units_power_1': 7, 'units_power_2': 7, 'units_power_3': 7, 'units_power_4': 9, 'dropout_0': 0.2848824961673906, 'dropout_1': 0.1063306509264842, 'dropout_2': 0.10209336841358861, 'dropout_3': 0.2636363167646512, 'dropout_4': 0.1088011511343344, 'use_residual_connection': False, 'use_attention_layer': False, 'use_conv1d': True, 'conv1d_filters': 5, 'conv1d_kernel_size': 4, 'l1_reg': 0.00030506045496513296, 'l2_reg': 0.00044666621339747495}. Best is trial 2 with value: 0.010382176280021471.
# mda: 0.4960000000000001
# loss diff: 0.15816754996776572
# std: -0.6517853736877441
# [I 2023-10-18 14:22:13,493] Trial 3 finished with value: 1.8338967881714545 and parameters: {'look_back': 88, 'num_layers': 7, 'layer_type_0': 'LSTM', 'layer_type_1': 'LSTM', 'layer_type_2': 'GRU', 'layer_type_3': 'LSTM', 'layer_type_4': 'LSTM', 'layer_type_5': 'GRU', 'layer_type_6': 'GRU', 'units_power_0': 7, 'units_power_1': 7, 'units_power_2': 8, 'units_power_3': 7, 'units_power_4': 7, 'units_power_5': 8, 'units_power_6': 8, 'dropout_0': 0.11152761090227384, 'dropout_1': 0.13018818133821394, 'dropout_2': 0.2102308026013624, 'dropout_3': 0.10598362969464795, 'dropout_4': 0.16199154187532813, 'dropout_5': 0.21517922043030374, 'dropout_6': 0.2190290790960075, 'use_residual_connection': False, 'use_attention_layer': False, 'use_conv1d': True, 'conv1d_filters': 6, 'conv1d_kernel_size': 3, 'l1_reg': 0.006074694673900172, 'l2_reg': 0.006874876413684306}. Best is trial 2 with value: 0.010382176280021471.
# mda: 0.4672661870503597
# loss diff: 0.30123305320739746
# std: 0.9999299220144167
# [I 2023-10-18 14:30:21,646] Trial 4 finished with value: 1.6666354557997558 and parameters: {'look_back': 81, 'num_layers': 8, 'layer_type_0': 'GRU', 'layer_type_1': 'LSTM', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'LSTM', 'layer_type_6': 'LSTM', 'layer_type_7': 'LSTM', 'units_power_0': 8, 'units_power_1': 8, 'units_power_2': 8, 'units_power_3': 7, 'units_power_4': 7, 'units_power_5': 9, 'units_power_6': 7, 'units_power_7': 9, 'dropout_0': 0.1873654134567066, 'dropout_1': 0.14454743410909066, 'dropout_2': 0.25706099673222826, 'dropout_3': 0.17893203978312266, 'dropout_4': 0.15468936469122135, 'dropout_5': 0.1495378925502786, 'dropout_6': 0.1540277189241332, 'dropout_7': 0.20386962789524637, 'use_residual_connection': False, 'use_attention_layer': True, 'use_conv1d': False, 'l1_reg': 2.019296805251675e-05, 'l2_reg': 0.00047557629047400386}. Best is trial 2 with value: 0.010382176280021471.
# mda: 0.4915619389587074
# loss diff: 0.16895298957824734
# std: 0.9892444051802158
# [I 2023-10-18 14:39:54,669] Trial 5 finished with value: 6.321049370912807 and parameters: {'look_back': 117, 'num_layers': 7, 'layer_type_0': 'LSTM', 'layer_type_1': 'LSTM', 'layer_type_2': 'GRU', 'layer_type_3': 'LSTM', 'layer_type_4': 'LSTM', 'layer_type_5': 'LSTM', 'layer_type_6': 'GRU', 'units_power_0': 9, 'units_power_1': 7, 'units_power_2': 8, 'units_power_3': 7, 'units_power_4': 8, 'units_power_5': 9, 'units_power_6': 9, 'dropout_0': 0.232292951921256, 'dropout_1': 0.17987478447994246, 'dropout_2': 0.17467051015777946, 'dropout_3': 0.23596145617580203, 'dropout_4': 0.19798467078747728, 'dropout_5': 0.16946424249613404, 'dropout_6': 0.2987887311698689, 'use_residual_connection': False, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 5, 'conv1d_kernel_size': 6, 'l1_reg': 0.006745017322236508, 'l2_reg': 0.0006382675235798234}. Best is trial 2 with value: 0.010382176280021471.
# mda: 0.43629764065335747
# loss diff: 2.7573470115661642
# std: 3
# [I 2023-10-18 14:47:38,032] Trial 6 finished with value: 1.7835209335549937 and parameters: {'look_back': 77, 'num_layers': 8, 'layer_type_0': 'GRU', 'layer_type_1': 'GRU', 'layer_type_2': 'GRU', 'layer_type_3': 'LSTM', 'layer_type_4': 'GRU', 'layer_type_5': 'GRU', 'layer_type_6': 'LSTM', 'layer_type_7': 'LSTM', 'units_power_0': 8, 'units_power_1': 8, 'units_power_2': 9, 'units_power_3': 7, 'units_power_4': 7, 'units_power_5': 8, 'units_power_6': 9, 'units_power_7': 8, 'dropout_0': 0.296737328931601, 'dropout_1': 0.10186991061754139, 'dropout_2': 0.11205765294419617, 'dropout_3': 0.2764806000892789, 'dropout_4': 0.2837746694660991, 'dropout_5': 0.1939967823237732, 'dropout_6': 0.15567968471368648, 'dropout_7': 0.20013232680604431, 'use_residual_connection': False, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 5, 'conv1d_kernel_size': 4, 'l1_reg': 8.460620600590637e-05, 'l2_reg': 2.1562772441937803e-05}. Best is trial 2 with value: 0.010382176280021471.
# mda: 0.48904847396768397
# loss diff: 0.3066082715988152
# std: 0.9659611359238625
# [I 2023-10-18 14:53:20,370] Trial 7 finished with value: 1.5874607045458973 and parameters: {'look_back': 97, 'num_layers': 5, 'layer_type_0': 'LSTM', 'layer_type_1': 'LSTM', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'GRU', 'units_power_0': 8, 'units_power_1': 8, 'units_power_2': 7, 'units_power_3': 9, 'units_power_4': 7, 'dropout_0': 0.18112714989890738, 'dropout_1': 0.1906194250021168, 'dropout_2': 0.2668185222955101, 'dropout_3': 0.152882566979295, 'dropout_4': 0.10394371946874251, 'use_residual_connection': False, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 7, 'conv1d_kernel_size': 5, 'l1_reg': 9.743308030016757e-05, 'l2_reg': 0.00011206935999124488}. Best is trial 2 with value: 0.010382176280021471.
# mda: 0.4996389891696751
# loss diff: 0.10793715715408325
# std: 0.9791625365614891
# [I 2023-10-18 15:01:13,054] Trial 8 finished with value: 2.557667398077551 and parameters: {'look_back': 87, 'num_layers': 8, 'layer_type_0': 'LSTM', 'layer_type_1': 'LSTM', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'LSTM', 
 'layer_type_0': 'GRU', 'layer_type_1': 'LSTM', 'layer_type_2': 'LSTM', 'layer_type_3': 'LSTM', 'layer_type_4': 'LSTM', 'units_power_0': 9, 'units_power_1': 9, 'units_power_2': 7, 'units_power_3': 8, 'units_power_4': 9, 'dropout_0': 0.25071179841655505, 'dropout_1': 0.2772426509126317, 'dropout_2': 0.11755341404878444, 'dropout_3': 0.25084563183051883, 'dropout_4': 0.14191202424488425, 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 5, 'conv1d_kernel_size': 5, 'l1_reg': 3.079542789613716e-05, 'l2_reg': 5.070543420635469e-05}. Best is trial 2 with value: 0.010382176280021471.
# mda: 0.48519855595667866
# loss diff: 0.15991480350494403
# std: 0.9953292217105627
# [I 2023-10-18 17:20:16,414] Trial 27 finished with value: 0.8649257694708327 and parameters: {'look_back': 92, 'num_layers': 6, 'layer_type_0': 'LSTM', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'GRU', 'layer_type_5': 'GRU', 'units_power_0': 9, 'units_power_1': 8, 'units_power_2': 8, 'units_power_3': 9, 'units_power_4': 9, 'units_power_5': 7, 'dropout_0': 0.28325821163110976, 'dropout_1': 0.22796640160126275, 'dropout_2': 0.16023766082435031, 'dropout_3': 0.2693131286299842, 'dropout_4': 0.1016933023216684, 'dropout_5': 0.23328431528805912, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': False, 'l1_reg': 0.00011237461256215404, 'l2_reg': 0.00012357370382900948}. Best is trial 2 with value: 0.010382176280021471.
# mda: 0.48216216216216223
# loss diff: 0.2075407028198235
# std: 0.1395472288131714
# [I 2023-10-18 17:25:30,084] Trial 28 finished with value: 1.6162356212882314 and parameters: {'look_back': 81, 'num_layers': 5, 'layer_type_0': 'LSTM', 'layer_type_1': 'LSTM', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'units_power_0': 7, 'units_power_1': 7, 'units_power_2': 8, 'units_power_3': 7, 'units_power_4': 8, 'dropout_0': 0.24875263305980302, 'dropout_1': 0.20277355231704236, 'dropout_2': 0.1334988031718008, 'dropout_3': 0.28060439893713873, 'dropout_4': 0.10313697166375609, 'use_residual_connection': False, 'use_attention_layer': False, 'use_conv1d': True, 'conv1d_filters': 6, 'conv1d_kernel_size': 3, 'l1_reg': 0.00038004755832538213, 'l2_reg': 9.059048243748593e-05}. Best is trial 2 with value: 0.010382176280021471.
# mda: 0.49012567324955114
# loss diff: 0.1301675349473952
# std: 0.9761937595903873
# [I 2023-10-18 17:33:24,253] Trial 29 finished with value: 1.7835004840146846 and parameters: {'look_back': 93, 'num_layers': 7, 'layer_type_0': 'LSTM', 'layer_type_1': 'GRU', 'layer_type_2': 'GRU', 'layer_type_3': 'LSTM', 'layer_type_4': 'LSTM', 'layer_type_5': 'GRU', 'layer_type_6': 'GRU', 'units_power_0': 8, 'units_power_1': 7, 'units_power_2': 9, 'units_power_3': 7, 'units_power_4': 9, 'units_power_5': 7, 'units_power_6': 8, 'dropout_0': 0.2845503889215047, 'dropout_1': 0.23408485852547573, 'dropout_2': 0.11016844498086878, 'dropout_3': 0.2818995798265782, 'dropout_4': 0.11784444201898242, 'dropout_5': 0.19121059232606413, 'dropout_6': 0.12392540155009206, 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': False, 'l1_reg': 0.00014005652841864782, 'l2_reg': 0.0008793861133849943}. Best is trial 2 with value: 0.010382176280021471.
# mda: 0.508108108108108
# loss diff: 0.3359812736511225
# std: 0.9556273184716702
# [I 2023-10-18 17:41:57,256] Trial 30 finished with value: 1.6201467639776792 and parameters: {'look_back': 121, 'num_layers': 6, 'layer_type_0': 'LSTM', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'GRU', 'layer_type_5': 'GRU', 'units_power_0': 9, 'units_power_1': 8, 'units_power_2': 9, 'units_power_3': 9, 'units_power_4': 8, 'units_power_5': 7, 'dropout_0': 0.28767919435482153, 'dropout_1': 0.1002454211837059, 'dropout_2': 0.19075296564861535, 'dropout_3': 0.2636866755901341, 'dropout_4': 0.15197993933524023, 'dropout_5': 0.21815541381836692, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': False, 'l1_reg': 7.209716100936214e-05, 'l2_reg': 4.615674344074703e-05}. Best is trial 2 with value: 0.010382176280021471.
# mda: 0.4829090909090909
# loss diff: 0.14099844694137564
# std: 0.9620574079453945
# [I 2023-10-18 17:49:35,665] Trial 31 finished with value: 1.488538864995982 and parameters: {'look_back': 94, 'num_layers': 6, 'layer_type_0': 'LSTM', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'GRU', 'layer_type_5': 'GRU', 'units_power_0': 9, 'units_power_1': 9, 'units_power_2': 7, 'units_power_3': 9, 'units_power_4': 9, 'units_power_5': 8, 'dropout_0': 0.2702757629424754, 'dropout_1': 0.22223234947325254, 'dropout_2': 0.15869767077946373, 'dropout_3': 0.24917778215957526, 'dropout_4': 0.1252991556611135, 'dropout_5': 0.2409593449155607, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': False, 'l1_reg': 2.6630872974338597e-05, 'l2_reg': 0.0003704704949989764}. Best is trial 2 with value: 0.010382176280021471.
# mda: 0.47675675675675677
# loss diff: 0.1063117027282714
# std: 0.8589839190244675
# [I 2023-10-18 17:57:42,015] Trial 32 finished with value: 1.4567171890755097 and parameters: {'look_back': 114, 'num_layers': 6, 'layer_type_0': 'LSTM', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'GRU', 'layer_type_5': 'GRU', 'units_power_0': 9, 'units_power_1': 8, 'units_power_2': 8, 'units_power_3': 9, 'units_power_4': 9, 'units_power_5': 7, 'dropout_0': 0.2635681019956764, 'dropout_1': 0.19913568050517144, 'dropout_2': 0.13955739879291695, 'dropout_3': 0.2657546459038238, 'dropout_4': 0.11402325111515663, 'dropout_5': 0.27098033253714776, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': False, 'l1_reg': 5.535721339408623e-05, 'l2_reg': 0.00013338340212981355}. Best is trial 2 with value: 0.010382176280021471.
# mda: 0.476950998185118
# loss diff: 0.1128258168697358
# std: 0.820842370390892
# [I 2023-10-18 18:03:39,058] Trial 33 finished with value: 1.4211516439057084 and parameters: {'look_back': 86, 'num_layers': 5, 'layer_type_0': 'LSTM', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'GRU', 'units_power_0': 8, 'units_power_1': 7, 'units_power_2': 8, 'units_power_3': 9, 'units_power_4': 9, 'dropout_0': 0.287700024698091, 'dropout_1': 0.22634268761688525, 'dropout_2': 0.1625339067852986, 'dropout_3': 0.2858607285511772, 'dropout_4': 0.10031112278486673, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': False, 'l1_reg': 1.0659317329541126e-05, 'l2_reg': 0.000349463638506596}. Best is trial 2 with value: 0.010382176280021471.
# mda: 0.4809352517985611
# loss diff: 0.04058216214179988
# std: 0.8615047335624695
# [I 2023-10-18 18:12:35,770] Trial 34 finished with value: 1.551148452491 and parameters: {'look_back': 107, 'num_layers': 7, 'layer_type_0': 'GRU', 'layer_type_1': 'GRU', 'layer_type_2': 'GRU', 'layer_type_3': 'GRU', 'layer_type_4': 'GRU', 'layer_type_5': 'GRU', 'layer_type_6': 'LSTM', 'units_power_0': 9, 'units_power_1': 9, 'units_power_2': 7, 'units_power_3': 9, 'units_power_4': 9, 'units_power_5': 8, 'units_power_6': 8, 'dropout_0': 0.26626616276198706, 'dropout_1': 0.24385017050019148, 'dropout_2': 0.18552253655107256, 'dropout_3': 0.27171126443173904, 'dropout_4': 0.1632785707522232, 'dropout_5': 0.22161535944904445, 'dropout_6': 0.19638112135236954, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': False, 'l1_reg': 2.469358429880455e-05, 'l2_reg': 0.0005489031714918345}. Best is trial 2 with value: 0.010382176280021471.
# [I 2023-10-18 18:12:35,780] A new study created in memory with name: no-name-299d0597-3553-40ab-ab35-d21aa5579ea4
# mda: 0.47862318840579715
# loss diff: 0.1046215295791626
# std: 0.9251501113176346
# Number of finished trials for NG_F:  35
# Best 5 trials:
# Rank 1 - Value: 0.010382176280021471, Params: {'look_back': 120, 'num_layers': 5, 'layer_type_0': 'LSTM', 'layer_type_1': 'LSTM', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'units_power_0': 7, 'units_power_1': 7, 'units_power_2': 7, 'units_power_3': 7, 'units_power_4': 9, 'dropout_0': 0.2848824961673906, 'dropout_1': 0.1063306509264842, 'dropout_2': 0.10209336841358861, 'dropout_3': 0.2636363167646512, 'dropout_4': 0.1088011511343344, 'use_residual_connection': False, 'use_attention_layer': False, 'use_conv1d': True, 'conv1d_filters': 5, 'conv1d_kernel_size': 4, 'l1_reg': 0.00030506045496513296, 'l2_reg': 0.00044666621339747495}
# Rank 2 - Value: 0.8649257694708327, Params: {'look_back': 92, 'num_layers': 6, 'layer_type_0': 'LSTM', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'GRU', 'layer_type_5': 'GRU', 'units_power_0': 9, 'units_power_1': 8, 'units_power_2': 8, 'units_power_3': 9, 'units_power_4': 9, 'units_power_5': 7, 'dropout_0': 0.28325821163110976, 'dropout_1': 0.22796640160126275, 'dropout_2': 0.16023766082435031, 'dropout_3': 0.2693131286299842, 'dropout_4': 0.1016933023216684, 'dropout_5': 0.23328431528805912, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': False, 'l1_reg': 0.00011237461256215404, 'l2_reg': 0.00012357370382900948}
# Rank 3 - Value: 1.212607007593617, Params: {'look_back': 103, 'num_layers': 5, 'layer_type_0': 'LSTM', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'GRU', 'units_power_0': 9, 'units_power_1': 9, 'units_power_2': 7, 'units_power_3': 8, 'units_power_4': 9, 'dropout_0': 0.2839579643746988, 'dropout_1': 0.27112433484237897, 'dropout_2': 0.14748117205079508, 'dropout_3': 0.28224607521723755, 'dropout_4': 0.10460129653154038, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': False, 'l1_reg': 2.4821452124853756e-05, 'l2_reg': 0.0002374858745321152}
# Rank 4 - Value: 1.3855929849915223, Params: {'look_back': 101, 'num_layers': 6, 'layer_type_0': 'LSTM', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'GRU', 'layer_type_5': 'LSTM', 'units_power_0': 9, 'units_power_1': 9, 'units_power_2': 7, 'units_power_3': 9, 'units_power_4': 9, 'units_power_5': 9, 'dropout_0': 0.2741532722611718, 'dropout_1': 0.22306257584477288, 'dropout_2': 0.1541540105825075, 'dropout_3': 0.21900122978733436, 'dropout_4': 0.12965655284544092, 'dropout_5': 0.2366326773569268, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': False, 'l1_reg': 3.4667785866788445e-05, 'l2_reg': 0.00017924588978304748}
# Rank 5 - Value: 1.3979700785056162, Params: {'look_back': 103, 'num_layers': 5, 'layer_type_0': 'LSTM', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'GRU', 'units_power_0': 9, 'units_power_1': 9, 'units_power_2': 7, 'units_power_3': 8, 'units_power_4': 9, 'dropout_0': 0.29856176115146127, 'dropout_1': 0.27517453489345217, 'dropout_2': 0.1485646215065724, 'dropout_3': 0.2992434770257091, 'dropout_4': 0.10135408435439028, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': False, 'l1_reg': 1.4980789525080141e-05, 'l2_reg': 1.4932651192388732e-05}
# [I 2023-10-18 18:18:26,893] Trial 0 finished with value: 3.393012198249071 and parameters: {'look_back': 114, 'num_layers': 5, 'layer_type_0': 'LSTM', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'GRU', 'units_power_0': 7, 'units_power_1': 7, 'units_power_2': 8, 'units_power_3': 9, 'units_power_4': 8, 'dropout_0': 0.2713809579079802, 'dropout_1': 0.2107708529217823, 'dropout_2': 0.21488844032397308, 'dropout_3': 0.19147926918276081, 'dropout_4': 0.10918744740980893, 'use_residual_connection': False, 'use_attention_layer': False, 'use_conv1d': False, 'l1_reg': 0.006274348388007584, 'l2_reg': 0.0316976171484661}. Best is trial 0 with value: 3.393012198249071.
# mda: 0.4119782214156079
# loss diff: 1.804990434646606
# std: 0.9999999850180732
# [I 2023-10-18 18:25:58,996] Trial 1 finished with value: 2.5765553969809765 and parameters: {'look_back': 76, 'num_layers': 7, 'layer_type_0': 'GRU', 'layer_type_1': 'LSTM', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'LSTM', 'layer_type_6': 'LSTM', 'units_power_0': 8, 'units_power_1': 8, 'units_power_2': 9, 'units_power_3': 9, 'units_power_4': 8, 'units_power_5': 9, 'units_power_6': 7, 'dropout_0': 0.21151415295930098, 'dropout_1': 0.17797420885026222, 'dropout_2': 0.21101996065988482, 'dropout_3': 0.2029290961455734, 'dropout_4': 0.27690703542254175, 'dropout_5': 0.27710752148318585, 'dropout_6': 0.20050462918089018, 'use_residual_connection': False, 'use_attention_layer': True, 'use_conv1d': False, 'l1_reg': 1.6212249124976243e-05, 'l2_reg': 7.215517036304223e-05}. Best is trial 1 with value: 2.5765553969809765.
# mda: 0.5086021505376344
# loss diff: 1.1207247976213692
# std: 0.9644327498972416
# [I 2023-10-18 18:34:46,337] Trial 2 finished with value: 2.5633888426132496 and parameters: {'look_back': 97, 'num_layers': 8, 'layer_type_0': 'LSTM', 'layer_type_1': 'LSTM', 'layer_type_2': 'LSTM', 'layer_type_3': 'LSTM', 'layer_type_4': 'LSTM', 'layer_type_5': 'LSTM', 'layer_type_6': 'GRU', 'layer_type_7': 'LSTM', 'units_power_0': 8, 'units_power_1': 8, 'units_power_2': 8, 'units_power_3': 7, 'units_power_4': 9, 'units_power_5': 7, 'units_power_6': 9, 'units_power_7': 8, 'dropout_0': 0.15082346251118367, 'dropout_1': 0.24238627429112186, 'dropout_2': 0.19864792026478229, 'dropout_3': 0.2256553740151584, 'dropout_4': 0.2530418933009801, 'dropout_5': 0.23757902502778316, 'dropout_6': 0.16941911750864688, 'dropout_7': 0.24464122574269073, 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': False, 'l1_reg': 0.0641989138348256, 'l2_reg': 7.887650155100924e-05}. Best is trial 2 with value: 2.5633888426132496.
# mda: 0.4646209386281589
# loss diff: 1.0280097961425696
# std: 0.9999999850988388
# [I 2023-10-18 18:41:18,513] Trial 3 finished with value: 2.284320478356876 and parameters: {'look_back': 105, 'num_layers': 5, 'layer_type_0': 'GRU', 'layer_type_1': 'LSTM', 'layer_type_2': 'GRU', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'units_power_0': 7, 'units_power_1': 8, 'units_power_2': 9, 'units_power_3': 9, 'units_power_4': 8, 'dropout_0': 0.1061078865786737, 'dropout_1': 0.1544277714234414, 'dropout_2': 0.11475524285161783, 'dropout_3': 0.2021173026025743, 'dropout_4': 0.28512364335425533, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': True, 'conv1d_filters': 7, 'conv1d_kernel_size': 4, 'l1_reg': 8.413211221172323e-05, 'l2_reg': 0.016333601756790345}. Best is trial 3 with value: 2.284320478356876.
# mda: 0.4900542495479205
# loss diff: 0.9422274872660638
# std: 0.8321472406387329
# [I 2023-10-18 18:47:32,392] Trial 4 finished with value: 2.5876868597311633 and parameters: {'look_back': 63, 'num_layers': 8, 'layer_type_0': 'LSTM', 'layer_type_1': 'LSTM', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'GRU', 'layer_type_6': 'GRU', 'layer_type_7': 'GRU', 'units_power_0': 7, 'units_power_1': 9, 'units_power_2': 8, 'units_power_3': 7, 'units_power_4': 7, 'units_power_5': 7, 'units_power_6': 7, 'units_power_7': 7, 'dropout_0': 0.1860633496270746, 'dropout_1': 0.2793508469752071, 'dropout_2': 0.1411391239084637, 'dropout_3': 0.1833330549500029, 'dropout_4': 0.2050618413439269, 'dropout_5': 0.11152442999771861, 'dropout_6': 0.27360754214338634, 'dropout_7': 0.2747019102410161, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': False, 'l1_reg': 0.0002078120734654674, 'l2_reg': 0.0030477456986613867}. Best is trial 3 with value: 2.284320478356876.
# mda: 0.4139285714285714
# loss diff: 1.059972196817398
# std: 0.9416432343423367
# [I 2023-10-18 18:56:13,602] Trial 5 finished with value: 2.0521102014638335 and parameters: {'look_back': 113, 'num_layers': 8, 'layer_type_0': 'LSTM', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'GRU', 'layer_type_6': 'GRU', 'layer_type_7': 'GRU', 'units_power_0': 9, 'units_power_1': 7, 'units_power_2': 8, 'units_power_3': 7, 'units_power_4': 7, 'units_power_5': 9, 'units_power_6': 7, 'units_power_7': 7, 'dropout_0': 0.28831543885790034, 'dropout_1': 0.13559099785459916, 'dropout_2': 0.2830649129366166, 'dropout_3': 0.13072242708854004, 'dropout_4': 0.17759813517188516, 'dropout_5': 0.1619705407971777, 'dropout_6': 0.14673402673263464, 'dropout_7': 0.20586162161589322, 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 7, 'conv1d_kernel_size': 7, 'l1_reg': 2.7121247347838402e-05, 'l2_reg': 0.0001301052855212031}. Best is trial 5 with value: 2.0521102014638335.
# mda: 0.3288566243194192
# loss diff: 0.6426268950104713
# std: 0.7383399307727814
# [I 2023-10-18 19:05:47,330] Trial 6 finished with value: 7.607011185379727 and parameters: {'look_back': 94, 'num_layers': 8, 'layer_type_0': 'LSTM', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'LSTM', 'layer_type_4': 'GRU', 'layer_type_5': 'GRU', 'layer_type_6': 'GRU', 'layer_type_7': 'GRU', 'units_power_0': 9, 'units_power_1': 9, 'units_power_2': 9, 'units_power_3': 7, 'units_power_4': 8, 'units_power_5': 7, 'units_power_6': 9, 'units_power_7': 7, 'dropout_0': 0.18384322824003912, 'dropout_1': 0.1769765881941052, 'dropout_2': 0.21619423550960826, 'dropout_3': 0.17924385840082951, 'dropout_4': 0.15172512292893275, 'dropout_5': 0.2866987232510624, 'dropout_6': 0.2792786750134042, 'dropout_7': 0.2441257225420247, 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 7, 'conv1d_kernel_size': 3, 'l1_reg': 0.0969416066088057, 'l2_reg': 0.017699745630070148}. Best is trial 5 with value: 2.0521102014638335.
# mda: 0.006846846846846846
# loss diff: 3.613858032226574
# std: 3
# [I 2023-10-18 19:10:46,351] Trial 7 finished with value: 2.727165163881916 and parameters: {'look_back': 88, 'num_layers': 5, 'layer_type_0': 'LSTM', 'layer_type_1': 'LSTM', 'layer_type_2': 'GRU', 'layer_type_3': 'GRU', 'layer_type_4': 'GRU', 'units_power_0': 7, 'units_power_1': 9, 'units_power_2': 8, 'units_power_3': 7, 'units_power_4': 7, 'dropout_0': 0.1295653203285667, 'dropout_1': 0.2855954638826377, 'dropout_2': 0.11668605409969675, 'dropout_3': 0.16539505300810345, 'dropout_4': 0.2307429611763781, 'use_residual_connection': False, 'use_attention_layer': False, 'use_conv1d': True, 'conv1d_filters': 7, 'conv1d_kernel_size': 6, 'l1_reg': 9.133114439571126e-05, 'l2_reg': 0.0025615676788592026}. Best is trial 5 with value: 2.0521102014638335.
# mda: 0.2618705035971223
# loss diff: 1.0795825213193893
# std: 0.9094531461596489
# [I 2023-10-18 19:18:00,653] Trial 8 finished with value: 2.723194006059657 and parameters: {'look_back': 120, 'num_layers': 5, 'layer_type_0': 'GRU', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'LSTM', 'layer_type_4': 'LSTM', 'units_power_0': 8, 'units_power_1': 7, 'units_power_2': 8, 'units_power_3': 8, 'units_power_4': 9, 'dropout_0': 0.18893104747539796, 'dropout_1': 0.2029958488655545, 'dropout_2': 0.17193692480821188, 'dropout_3': 0.2638786522753648, 'dropout_4': 0.2606188105853947, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': True, 'conv1d_filters': 5, 'conv1d_kernel_size': 7, 'l1_reg': 8.65134819385708e-05, 'l2_reg': 0.035820383777012424}. Best is trial 5 with value: 2.0521102014638335.
# mda: 0.29963636363636365
# loss diff: 1.0640624936670064
# std: 0.9587678760290146
# [I 2023-10-18 19:24:00,222] Trial 9 finished with value: 2.0955680896244617 and parameters: {'look_back': 109, 'num_layers': 5, 'layer_type_0': 'GRU', 'layer_type_1': 'LSTM', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'units_power_0': 7, 'units_power_1': 8, 'units_power_2': 8, 'units_power_3': 9, 'units_power_4': 7, 'dropout_0': 0.28303707249353816, 'dropout_1': 0.1562374271830366, 'dropout_2': 0.2901556228939658, 'dropout_3': 0.1178925964381183, 'dropout_4': 0.15340513546603513, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': True, 'conv1d_filters': 7, 'conv1d_kernel_size': 4, 'l1_reg': 2.1608982446611552e-05, 'l2_reg': 0.0002567872667567271}. Best is trial 5 with value: 2.0521102014638335.
# mda: 0.49347826086956526
# loss diff: 0.7126081649214029
# std: 0.8764381855726242
# [I 2023-10-18 19:31:53,659] Trial 10 finished with value: 4.037204124758405 and parameters: {'look_back': 121, 'num_layers': 7, 'layer_type_0': 'LSTM', 'layer_type_1': 'GRU', 'layer_type_2': 'GRU', 'layer_type_3': 'LSTM', 'layer_type_4': 'GRU', 'layer_type_5': 'GRU', 'layer_type_6': 'LSTM', 'units_power_0': 9, 'units_power_1': 7, 'units_power_2': 7, 'units_power_3': 8, 'units_power_4': 7, 'units_power_5': 9, 'units_power_6': 7, 'dropout_0': 0.2951098882887308, 'dropout_1': 0.11322405029387543, 'dropout_2': 0.29613806743840454, 'dropout_3': 0.10043262127336589, 'dropout_4': 0.1896666326811759, 'dropout_5': 0.1674580302739384, 'dropout_6': 0.10473353874770003, 'use_residual_connection': False, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 6, 'conv1d_kernel_size': 7, 'l1_reg': 0.000910837796007663, 'l2_reg': 1.2619366016191682e-05}. Best is trial 5 with value: 2.0521102014638335.
# mda: 0.10400000000000001
# loss diff: 2.1412118852138518
# std: 0.9999922395445537
# [I 2023-10-18 19:39:09,047] Trial 11 finished with value: 2.670325637054022 and parameters: {'look_back': 108, 'num_layers': 6, 'layer_type_0': 'GRU', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'GRU', 'units_power_0': 9, 'units_power_1': 7, 'units_power_2': 7, 'units_power_3': 8, 'units_power_4': 7, 'units_power_5': 9, 'dropout_0': 0.2567640631308048, 'dropout_1': 0.11889438499692599, 'dropout_2': 0.29014003807399, 'dropout_3': 0.11533099292257389, 'dropout_4': 0.16355999810033542, 'dropout_5': 0.17694565811506968, 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 6, 'conv1d_kernel_size': 5, 'l1_reg': 1.1163415186697806e-05, 'l2_reg': 0.0003978602301703571}. Best is trial 5 with value: 2.0521102014638335.
# mda: 0.44021739130434784
# loss diff: 1.1336950817145408
# std: 0.9768479466438293
# [I 2023-10-18 19:46:01,709] Trial 12 finished with value: 2.5652442364133288 and parameters: {'look_back': 105, 'num_layers': 6, 'layer_type_0': 'GRU', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'GRU', 'units_power_0': 9, 'units_power_1': 8, 'units_power_2': 7, 'units_power_3': 9, 'units_power_4': 7, 'units_power_5': 8, 'dropout_0': 0.2958176058596051, 'dropout_1': 0.14260064433869793, 'dropout_2': 0.2571301662362322, 'dropout_3': 0.13632719912156607, 'dropout_4': 0.14400008878952014, 'dropout_5': 0.12982359288363343, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': True, 'conv1d_filters': 7, 'conv1d_kernel_size': 4, 'l1_reg': 1.731851222746789e-05, 'l2_reg': 0.0004181332316677658}. Best is trial 5 with value: 2.0521102014638335.
# mda: 0.4893309222423146
# loss diff: 1.1381981506943704
# std: 0.9163770079612732
# [I 2023-10-18 19:54:20,611] Trial 13 finished with value: 2.5374773411696605 and parameters: {'look_back': 124, 'num_layers': 7, 'layer_type_0': 'GRU', 'layer_type_1': 'LSTM', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'LSTM', 'layer_type_6': 'GRU', 'units_power_0': 8, 'units_power_1': 7, 'units_power_2': 8, 'units_power_3': 8, 'units_power_4': 7, 'units_power_5': 8, 'units_power_6': 8, 'dropout_0': 0.24631026257855887, 'dropout_1': 0.10860209251034326, 'dropout_2': 0.26265137331136124, 'dropout_3': 0.1401876779767325, 'dropout_4': 0.1875365912544763, 'dropout_5': 0.2019165506475547, 'dropout_6': 0.11161269575130159, 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 6, 'conv1d_kernel_size': 5, 'l1_reg': 1.0555119070964932e-05, 'l2_reg': 0.00017646284275373998}. Best is trial 5 with value: 2.0521102014638335.
# mda: 0.5298181818181817
# loss diff: 1.1079358845949172
# std: 0.9593596383929253
# ...
# mda: 0.48892921960072594
# loss diff: 0.6515376884490252
# std: 0.8762893751263618
# [I 2023-10-18 21:09:03,201] Trial 23 finished with value: 2.0693713789369688 and parameters: {'look_back': 117, 'num_layers': 6, 'layer_type_0': 'GRU', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'GRU', 'units_power_0': 7, 'units_power_1': 9, 'units_power_2': 8, 'units_power_3': 9, 'units_power_4': 7, 'units_power_5': 9, 'dropout_0': 0.28341169546529116, 'dropout_1': 0.12621439024910802, 'dropout_2': 0.2431138663312405, 'dropout_3': 0.10375304813384639, 'dropout_4': 0.13355495368151457, 'dropout_5': 0.1272442588049137, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': True, 'conv1d_filters': 7, 'conv1d_kernel_size': 5, 'l1_reg': 5.173952189933482e-05, 'l2_reg': 0.00010863265577677912}. Best is trial 22 with value: 2.0388978439746612.
# mda: 0.4932849364791288
# loss diff: 0.712066637724638
# std: 0.8505896776914597
# [I 2023-10-18 21:17:19,582] Trial 24 finished with value: 2.530456512234767 and parameters: {'look_back': 118, 'num_layers': 6, 'layer_type_0': 'GRU', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'GRU', 'units_power_0': 7, 'units_power_1': 9, 'units_power_2': 8, 'units_power_3': 9, 'units_power_4': 7, 'units_power_5': 9, 'dropout_0': 0.2582253542638114, 'dropout_1': 0.12959019660715046, 'dropout_2': 0.27344706417597814, 'dropout_3': 0.12905203647794855, 'dropout_4': 0.14176128520030576, 'dropout_5': 0.13639837951504963, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': True, 'conv1d_filters': 7, 'conv1d_kernel_size': 5, 'l1_reg': 0.0001616343803046841, 'l2_reg': 7.705875914211239e-05}. Best is trial 22 with value: 2.0388978439746612.
# mda: 0.4921960072595281
# loss diff: 1.060522684454918
# std: 0.9621298350393772
# [I 2023-10-18 21:25:25,163] Trial 25 finished with value: 3.5196767110762925 and parameters: {'look_back': 117, 'num_layers': 7, 'layer_type_0': 'GRU', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'GRU', 'layer_type_6': 'LSTM', 'units_power_0': 8, 'units_power_1': 9, 'units_power_2': 7, 'units_power_3': 9, 'units_power_4': 8, 'units_power_5': 9, 'units_power_6': 7, 'dropout_0': 0.2810581700855951, 'dropout_1': 0.1011581413001995, 'dropout_2': 0.2489571131109143, 'dropout_3': 0.114800468895058, 'dropout_4': 0.12190182620519516, 'dropout_5': 0.1270014073436359, 'dropout_6': 0.23271958826073322, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': True, 'conv1d_filters': 6, 'conv1d_kernel_size': 6, 'l1_reg': 6.983926701417417e-05, 'l2_reg': 0.0007623022777684944}. Best is trial 22 with value: 2.0388978439746612.
# mda: 0.4896551724137931
# loss diff: 2.1734132334589957
# std: 0.8359186500310898
# [I 2023-10-18 21:33:42,486] Trial 26 finished with value: 2.091552210164341 and parameters: {'look_back': 121, 'num_layers': 6, 'layer_type_0': 'LSTM', 'layer_type_1': 'GRU', 'layer_type_2': 'GRU', 'layer_type_3': 'LSTM', 'layer_type_4': 'GRU', 'layer_type_5': 'GRU', 'units_power_0': 7, 'units_power_1': 9, 'units_power_2': 9, 'units_power_3': 8, 'units_power_4': 7, 'units_power_5': 9, 'dropout_0': 0.26617538846477223, 'dropout_1': 0.11860099468458188, 'dropout_2': 0.2742179225718866, 'dropout_3': 0.16345650504581657, 'dropout_4': 0.17222020143755193, 'dropout_5': 0.15032363727954293, 'use_residual_connection': False, 'use_attention_layer': True, 'use_conv1d': False, 'l1_reg': 1.078884503774401e-05, 'l2_reg': 0.000306078597117025}. Best is trial 22 with value: 2.0388978439746612.
# mda: 0.514909090909091
# loss diff: 0.7167970459908247
# std: 0.8896642550826073
# [I 2023-10-18 21:42:16,204] Trial 27 finished with value: 1.684553184875033 and parameters: {'look_back': 124, 'num_layers': 7, 'layer_type_0': 'GRU', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'GRU', 'layer_type_6': 'GRU', 'units_power_0': 7, 'units_power_1': 9, 'units_power_2': 8, 'units_power_3': 8, 'units_power_4': 7, 'units_power_5': 8, 'units_power_6': 8, 'dropout_0': 0.2871933710554576, 'dropout_1': 0.13860894105759478, 'dropout_2': 0.22802989326108172, 'dropout_3': 0.13799107039054923, 'dropout_4': 0.16318209215231644, 'dropout_5': 0.12470869780533785, 'dropout_6': 0.155702927085387, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': True, 'conv1d_filters': 7, 'conv1d_kernel_size': 5, 'l1_reg': 2.8660561087306903e-05, 'l2_reg': 0.00011747955509591223}. Best is trial 27 with value: 1.684553184875033.
# mda: 0.5072727272727273
# loss diff: 0.3905031688511371
# std: 0.8013227432966232
# [I 2023-10-18 21:51:13,557] Trial 28 finished with value: 2.8641192388588728 and parameters: {'look_back': 124, 'num_layers': 8, 'layer_type_0': 'LSTM', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'GRU', 'layer_type_6': 'GRU', 'layer_type_7': 'LSTM', 'units_power_0': 9, 'units_power_1': 8, 'units_power_2': 8, 'units_power_3': 7, 'units_power_4': 8, 'units_power_5': 8, 'units_power_6': 8, 'units_power_7': 7, 'dropout_0': 0.24946695589415332, 'dropout_1': 0.14085564124349398, 'dropout_2': 0.27987002763216084, 'dropout_3': 0.14548748040567144, 'dropout_4': 0.1655137558748523, 'dropout_5': 0.16344723209613277, 'dropout_6': 0.15151095176861062, 'dropout_7': 0.1738164053539108, 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 7, 'conv1d_kernel_size': 6, 'l1_reg': 2.3453196878537745e-05, 'l2_reg': 1.0604251081931256e-05}. Best is trial 27 with value: 1.684553184875033.
# mda: 0.5221818181818183
# loss diff: 1.4283107757568358
# std: 0.9579902812838554
# [I 2023-10-18 22:00:09,166] Trial 29 finished with value: 2.834309244044783 and parameters: {'look_back': 112, 'num_layers': 8, 'layer_type_0': 'LSTM', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'GRU', 'layer_type_5': 'GRU', 'layer_type_6': 'GRU', 'layer_type_7': 'GRU', 'units_power_0': 7, 'units_power_1': 9, 'units_power_2': 8, 'units_power_3': 8, 'units_power_4': 8, 'units_power_5': 8, 'units_power_6': 9, 'units_power_7': 8, 'dropout_0': 0.26796329608625563, 'dropout_1': 0.1840295391423744, 'dropout_2': 0.257840789241045, 'dropout_3': 0.1350355948897501, 'dropout_4': 0.11340726848197676, 'dropout_5': 0.10139672160333861, 'dropout_6': 0.13093865309577501, 'dropout_7': 0.10215976719553843, 'use_residual_connection': False, 'use_attention_layer': False, 'use_conv1d': False, 'l1_reg': 0.0004766777616449592, 'l2_reg': 4.597898962531428e-05}. Best is trial 27 with value: 1.684553184875033.
# mda: 0.47934782608695653
# loss diff: 1.313713490962982
# std: 0.9999435791687574
# [I 2023-10-18 22:08:01,883] Trial 30 finished with value: 5.507990162688461 and parameters: {'look_back': 114, 'num_layers': 7, 'layer_type_0': 'GRU', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'GRU', 'layer_type_6': 'GRU', 'units_power_0': 8, 'units_power_1': 7, 'units_power_2': 8, 'units_power_3': 8, 'units_power_4': 7, 'units_power_5': 8, 'units_power_6': 8, 'dropout_0': 0.2772224339428704, 'dropout_1': 0.1948024228765873, 'dropout_2': 0.21926980201350083, 'dropout_3': 0.17076118291989045, 'dropout_4': 0.18654791885866562, 'dropout_5': 0.14968393685857947, 'dropout_6': 0.17575812196992016, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': True, 'conv1d_filters': 6, 'conv1d_kernel_size': 5, 'l1_reg': 0.004848548164938385, 'l2_reg': 0.0002613223140587392}. Best is trial 27 with value: 1.684553184875033.
# mda: 0.37205081669691464
# loss diff: 1.8800409793853756
# std: 3
# [I 2023-10-18 22:16:12,971] Trial 31 finished with value: 2.484530303085023 and parameters: {'look_back': 117, 'num_layers': 6, 'layer_type_0': 'GRU', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'GRU', 'units_power_0': 7, 'units_power_1': 9, 'units_power_2': 8, 'units_power_3': 9, 'units_power_4': 7, 'units_power_5': 9, 'dropout_0': 0.28465355605948167, 'dropout_1': 0.12697317332456642, 'dropout_2': 0.23043240268711918, 'dropout_3': 0.10974323542581828, 'dropout_4': 0.14205984083404524, 'dropout_5': 0.12784159882692114, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': True, 'conv1d_filters': 7, 'conv1d_kernel_size': 5, 'l1_reg': 4.607786711149157e-05, 'l2_reg': 9.970696944576489e-05}. Best is trial 27 with value: 1.684553184875033.
# mda: 0.4823956442831216
# loss diff: 1.037943458557129
# std: 0.9289824888110161
# [I 2023-10-18 22:24:41,883] Trial 32 finished with value: 2.5026044991910457 and parameters: {'look_back': 124, 'num_layers': 7, 'layer_type_0': 'GRU', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'GRU', 'layer_type_6': 'GRU', 'units_power_0': 7, 'units_power_1': 9, 'units_power_2': 8, 'units_power_3': 9, 'units_power_4': 7, 'units_power_5': 9, 'units_power_6': 7, 'dropout_0': 0.28276112467185416, 'dropout_1': 0.1423968583411024, 'dropout_2': 0.23039947413009915, 'dropout_3': 0.1263107132458467, 'dropout_4': 0.1080918162997513, 'dropout_5': 0.12220448465471957, 'dropout_6': 0.13059863918101816, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': True, 'conv1d_filters': 7, 'conv1d_kernel_size': 5, 'l1_reg': 1.881500220254179e-05, 'l2_reg': 0.00012975057128504307}. Best is trial 27 with value: 1.684553184875033.
# mda: 0.41200000000000003
# loss diff: 0.949448323994875
# std: 0.9651561751961708
# [I 2023-10-18 22:31:06,616] Trial 33 finished with value: 2.541057508270587 and parameters: {'look_back': 76, 'num_layers': 7, 'layer_type_0': 'GRU', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'GRU', 'layer_type_6': 'GRU', 'units_power_0': 7, 'units_power_1': 9, 'units_power_2': 8, 'units_power_3': 9, 'units_power_4': 7, 'units_power_5': 8, 'units_power_6': 9, 'dropout_0': 0.26828867102870146, 'dropout_1': 0.11376285177060501, 'dropout_2': 0.20510523122673402, 'dropout_3': 0.14925351716087515, 'dropout_4': 0.15346727801257848, 'dropout_5': 0.13951078502980635, 'dropout_6': 0.17764373673152994, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': True, 'conv1d_filters': 7, 'conv1d_kernel_size': 5, 'l1_reg': 0.00012702702932083077, 'l2_reg': 5.771232768546466e-05}. Best is trial 27 with value: 1.684553184875033.
# mda: 0.4806451612903226
# loss diff: 1.1505775079131126
# std: 0.8711251616477966
# [I 2023-10-18 22:41:14,640] Trial 34 finished with value: 1.7842944581628495 and parameters: {'look_back': 107, 'num_layers': 8, 'layer_type_0': 'GRU', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'GRU', 'layer_type_6': 'GRU', 'layer_type_7': 'GRU', 'units_power_0': 7, 'units_power_1': 9, 'units_power_2': 9, 'units_power_3': 7, 'units_power_4': 7, 'units_power_5': 9, 'units_power_6': 8, 'units_power_7': 9, 'dropout_0': 0.28961981971581047, 'dropout_1': 0.12634445169844227, 'dropout_2': 0.24923693374503664, 'dropout_3': 0.11697379880664693, 'dropout_4': 0.1303409134813648, 'dropout_5': 0.12111743644299905, 'dropout_6': 0.15504723977271312, 'dropout_7': 0.2047108059473951, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': False, 'l1_reg': 6.96565873089309e-05, 'l2_reg': 0.00010526657389437929}. Best is trial 27 with value: 1.684553184875033.
# mda: 0.5130434782608695
# loss diff: 0.3100103914737702
# std: 0.9873275449499488
# Number of finished trials for NVDA:  35
# Best 5 trials:
# Rank 1 - Value: 1.684553184875033, Params: {'look_back': 124, 'num_layers': 7, 'layer_type_0': 'GRU', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'GRU', 'layer_type_6': 'GRU', 'units_power_0': 7, 'units_power_1': 9, 'units_power_2': 8, 'units_power_3': 8, 'units_power_4': 7, 'units_power_5': 8, 'units_power_6': 8, 'dropout_0': 0.2871933710554576, 'dropout_1': 0.13860894105759478, 'dropout_2': 0.22802989326108172, 'dropout_3': 0.13799107039054923, 'dropout_4': 0.16318209215231644, 'dropout_5': 0.12470869780533785, 'dropout_6': 0.155702927085387, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': True, 'conv1d_filters': 7, 'conv1d_kernel_size': 5, 'l1_reg': 2.8660561087306903e-05, 'l2_reg': 0.00011747955509591223}
# Rank 2 - Value: 1.7842944581628495, Params: {'look_back': 107, 'num_layers': 8, 'layer_type_0': 'GRU', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'GRU', 'layer_type_6': 'GRU', 'layer_type_7': 'GRU', 'units_power_0': 7, 'units_power_1': 9, 'units_power_2': 9, 'units_power_3': 7, 'units_power_4': 7, 'units_power_5': 9, 'units_power_6': 8, 'units_power_7': 9, 'dropout_0': 0.28961981971581047, 'dropout_1': 0.12634445169844227, 'dropout_2': 0.24923693374503664, 'dropout_3': 0.11697379880664693, 'dropout_4': 0.1303409134813648, 'dropout_5': 0.12111743644299905, 'dropout_6': 0.15504723977271312, 'dropout_7': 0.2047108059473951, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': False, 'l1_reg': 6.96565873089309e-05, 'l2_reg': 0.00010526657389437929}
# Rank 3 - Value: 2.0388978439746612, Params: {'look_back': 117, 'num_layers': 6, 'layer_type_0': 'GRU', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'GRU', 'units_power_0': 7, 'units_power_1': 9, 'units_power_2': 8, 'units_power_3': 9, 'units_power_4': 7, 'units_power_5': 9, 'dropout_0': 0.2797140462242804, 'dropout_1': 0.13239047419075983, 'dropout_2': 0.2746119921000069, 'dropout_3': 0.11587683997483302, 'dropout_4': 0.13630611490482392, 'dropout_5': 0.12856304812712593, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': True, 'conv1d_filters': 7, 'conv1d_kernel_size': 5, 'l1_reg': 2.3457662385396532e-05, 'l2_reg': 0.000223750037350684}
# Rank 4 - Value: 2.0521102014638335, Params: {'look_back': 113, 'num_layers': 8, 'layer_type_0': 'LSTM', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'GRU', 'layer_type_6': 'GRU', 'layer_type_7': 'GRU', 'units_power_0': 9, 'units_power_1': 7, 'units_power_2': 8, 'units_power_3': 7, 'units_power_4': 7, 'units_power_5': 9, 'units_power_6': 7, 'units_power_7': 7, 'dropout_0': 0.28831543885790034, 'dropout_1': 0.13559099785459916, 'dropout_2': 0.2830649129366166, 'dropout_3': 0.13072242708854004, 'dropout_4': 0.17759813517188516, 'dropout_5': 0.1619705407971777, 'dropout_6': 0.14673402673263464, 'dropout_7': 0.20586162161589322, 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 7, 'conv1d_kernel_size': 7, 'l1_reg': 2.7121247347838402e-05, 'l2_reg': 0.0001301052855212031}
# Rank 5 - Value: 2.0693713789369688, Params: {'look_back': 117, 'num_layers': 6, 'layer_type_0': 'GRU', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'GRU', 'units_power_0': 7, 'units_power_1': 9, 'units_power_2': 8, 'units_power_3': 9, 'units_power_4': 7, 'units_power_5': 9, 'dropout_0': 0.28341169546529116, 'dropout_1': 0.12621439024910802, 'dropout_2': 0.2431138663312405, 'dropout_3': 0.10375304813384639, 'dropout_4': 0.13355495368151457, 'dropout_5': 0.1272442588049137, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': True, 'conv1d_filters': 7, 'conv1d_kernel_size': 5, 'l1_reg': 5.173952189933482e-05, 'l2_reg': 0.00010863265577677912}

# %% [markdown]
# # Prédiction de l'ensemble des features

# %% [markdown]
# Ici, nous allons mettre en concurrence 3 types de modèle de prédiction (CNN : GRU/LSTM), XGBoost, SARIMA)  et choisir le meilleur pour chacune des caractéristiques, on peut donc se retrouver avec un système hybride en amont pour les features d'entrée du modèle final.

# %% [markdown]
# ### Création des modèles pour chaque features:

# %% [markdown]
# #### Modèle de réseaux de neurones:

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True)

def create_single_output_sequences(data, index_name, look_back=1):
    X, y = [], []
    feature_columns = ['Close']
    for i in range(look_back, len(data)):
        sequence_data = data.loc[data.index[i-look_back:i], [(index_name, col) for col in feature_columns]].values
        X.append(sequence_data)
        y.append(data.loc[data.index[i], [(index_name, 'Close')]].values[0])
    return np.array(X), np.array(y)

def recursive_prediction_multi_output(model, initial_input, steps):
    recursive_predictions = []  # Une liste pour stocker les prédictions à chaque étape
    current_input = initial_input.copy()  # Copie de l'entrée initiale pour éviter les modifications indésirables

    for i in range(steps):
        # Faire une prédiction pour le jour suivant en utilisant l'entrée actuelle
        predicted_values = model.predict(current_input.to_numpy().reshape(1, current_input.shape[0], current_input.shape[1]))
        
        # Ajouter ces prédictions à notre liste
        recursive_predictions.append(predicted_values[0])
        
        # Préparer l'entrée pour la prochaine prédiction
        # Supprimer la première valeur (jour le plus ancien)
        current_input = current_input.shift(-1)
        # Ajouter la nouvelle valeur prédite à la fin de l'entrée
        current_input.iloc[-1:] = pd.DataFrame(predicted_values)

    return np.array(recursive_predictions)

# Dictionnaires pour stocker les modèles et leurs performances
gru_models = {}
mse_gru = {}
recursive_preds_gru = {}
all_preds_gru = {}

for index_name in final_df.columns.get_level_values(0).unique():  # Parcourir chaque indice
    # Sélectionner hyperparamètre optimaux
    top_n_params = top_n_trials_per_feature[index_name]
    best_rmse = float('inf') 
    best_model = None
    all_predictions_for_index = []
    
    for rank, best_params in enumerate(top_n_params, 1):
        print(f"Training for {index_name} with configuration rank {rank}")
        look_back=best_params['look_back']

        # Créer des séquences pour l'entraînement et les tests
        X_train, y_train = create_single_output_sequences(train_data, index_name , look_back)
        X_test, y_test = create_single_output_sequences(test_data, index_name ,look_back)

        # Create the neural network model
        model = create_model(
            num_layers=best_params['num_layers'],
            units_per_layer=[2 ** (best_params[f'units_power_{i}']) for i in range(best_params['num_layers'])],
            layer_type=[best_params[f'layer_type_{i}'] for i in range(best_params['num_layers'])],
            dropout_per_layer=[best_params[f'dropout_{i}'] for i in range(best_params['num_layers'])],
            input_shape=(X_train.shape[1], 1),
            use_conv1d=best_params['use_conv1d'],
            conv1d_filters=2 ** best_params['conv1d_filters'] if best_params['use_conv1d'] else None,
            conv1d_kernel_size=best_params.get('conv1d_kernel_size', None),
            use_residual_connection=best_params['use_residual_connection'],
            attention_layer=best_params['use_attention_layer'],
            l1_reg=best_params['l1_reg'],
            l2_reg=best_params['l2_reg']
        )

        # Entraîner le modèle
        history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=1000, batch_size=64, callbacks=[early_stopping])

        # Évaluer le modèle

        # Initial input: X dernières observations du jeu de données d'entraînement
        initial_input = train_data[[(index_name, 'Close')]][-look_back:]

        # Prédictions récursives
        predictions = recursive_prediction_multi_output(model, initial_input, len(test_data))
        
        all_predictions_for_index.append(predictions)

        # Initialisation
        inverse_predictions = np.zeros_like(predictions)
        inverse_real_values = np.zeros_like(y_test)

        # Parcourir chaque caractéristique et chaque indice
        for idx, feature_name in enumerate(['Close']):
            scaler_key = (index_name, feature_name)  # Créer la clé pour accéder au bon scaler dans le dictionnaire
            feature_scaler = scalers_dict[scaler_key]  # Récupérer le scaler correspondant

            # Inverser la mise à l'échelle pour les prédictions et les valeurs réelles
            inverse_predictions = feature_scaler.inverse_transform(predictions.reshape(-1, 1)).flatten()
            inverse_real_values_test = feature_scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()

            # Utilisez le scaler pour inverser la mise à l'échelle des dernières valeurs réelles de l'ensemble d'entraînement
            last_real_values_train_scaled = train_data[(index_name, 'Close')].iloc[-len(y_test):].values
            last_real_values_train = feature_scaler.inverse_transform(last_real_values_train_scaled.reshape(-1, 1)).flatten()

            # Concaténer les dernières valeurs réelles de l'ensemble d'entraînement avec les vraies valeurs de l'ensemble de test
            real_values = np.concatenate([last_real_values_train, inverse_real_values_test])

            # Concaténer les dernières valeurs réelles de l'ensemble d'entraînement avec les valeurs prédites
            predicted_values = np.concatenate([last_real_values_train, inverse_predictions])
            
            # Appliquer le filtre gaussien
            sigma = 5
            smoothed_values_test = gaussian_filter1d(y_test, sigma)
            smoothed_values = gaussian_filter1d(real_values, sigma)

            rmse = weighted_rmse(smoothed_values_test, np.array(predictions), len(smoothed_values_test))
            if np.std(predictions) > 1e-3:
                if rmse < best_rmse:
                    best_rmse = rmse
                    best_model = model
                    
                    # Stockez les prédictions pour cette caractéristique
                    recursive_preds_gru[scaler_key] = inverse_predictions
            else:
                print("Les prédictions sont constantes.")
            
            plt.plot(real_values, label='Real Close Values', color='blue')
            plt.plot(smoothed_values, label='Smoothed Real Close Values', color='green')
            plt.plot(predicted_values, label='Predicted Close Values', color='red', linestyle='--')
            plt.title(f"Evolution of Real vs Predicted Close Values for {index_name} with CNN")
            plt.legend()
            plt.show()

            # Stocker le modèle et sa performance
            gru_models[scaler_key] = best_model
            mse_gru[scaler_key] = best_rmse
        print(f"Feature: {index_name} - RMSE: {rmse}")
    
    # Calculer la médiane des prédictions pour l'indice
    median_predictions = np.median(all_predictions_for_index, axis=0)
    # Évaluer la RMSE de la médiane des prédiction
    rmse_median = weighted_rmse(smoothed_values_test, np.array(median_predictions), len(smoothed_values_test))
    
        # Comparer la RMSE de la médiane avec la meilleure RMSE individuelle
    if rmse_median < best_rmse:
        print(f"La médiane des prédictions est meilleure pour l'indice {index_name}. RMSE: {rmse_median}")
        recursive_preds_gru[scaler_key] = feature_scaler.inverse_transform(median_predictions.reshape(-1, 1)).flatten()
        mse_gru[scaler_key] = rmse_median
        all_preds_gru[index_name] = median_predictions  # Stocker la médiane des prédictions
    else:
        print(f"Le meilleur modèle unique est meilleur pour l'indice {index_name}. RMSE: {best_rmse}")
        all_preds_gru[index_name] = feature_scaler.inverse_transform(np.array(best_model.predict(X_test)).reshape(-1, 1)).flatten()

print("Entraînement des modèles de réseau neuronal terminé.")
# Out:
# Training for NG_F with configuration rank 1
# Epoch 1/1000
# 52/52 [==============================] - 21s 220ms/step - loss: 11.2870 - val_loss: 4.9737
# Epoch 2/1000
# 52/52 [==============================] - 9s 173ms/step - loss: 2.8781 - val_loss: 1.5716
# Epoch 3/1000
# 52/52 [==============================] - 9s 177ms/step - loss: 1.1581 - val_loss: 0.8163
# Epoch 4/1000
# 52/52 [==============================] - 9s 176ms/step - loss: 0.6488 - val_loss: 0.4645
# Epoch 5/1000
# 52/52 [==============================] - 9s 174ms/step - loss: 0.3945 - val_loss: 0.2983
# Epoch 6/1000
# 52/52 [==============================] - 9s 179ms/step - loss: 0.2637 - val_loss: 0.2128
# Epoch 7/1000
# 52/52 [==============================] - 9s 181ms/step - loss: 0.2024 - val_loss: 0.1736
# Epoch 8/1000
# 52/52 [==============================] - 9s 180ms/step - loss: 0.1617 - val_loss: 0.1419
# Epoch 9/1000
# 52/52 [==============================] - 9s 181ms/step - loss: 0.1455 - val_loss: 0.1246
# Epoch 10/1000
# 52/52 [==============================] - 9s 178ms/step - loss: 0.1314 - val_loss: 0.1144
# Epoch 11/1000
# 52/52 [==============================] - 9s 182ms/step - loss: 0.1259 - val_loss: 0.1263
# Epoch 12/1000
# 52/52 [==============================] - 10s 185ms/step - loss: 0.1266 - val_loss: 0.1031
# Epoch 13/1000
# 52/52 [==============================] - 11s 206ms/step - loss: 0.1097 - val_loss: 0.0969
# Epoch 14/1000
# 52/52 [==============================] - 11s 205ms/step - loss: 0.1052 - val_loss: 0.0946
# Epoch 15/1000
# 52/52 [==============================] - 10s 199ms/step - loss: 0.1016 - val_loss: 0.0908
# Epoch 16/1000
# 52/52 [==============================] - 10s 200ms/step - loss: 0.1010 - val_loss: 0.0907
# Epoch 17/1000
# 52/52 [==============================] - 10s 191ms/step - loss: 0.1220 - val_loss: 0.0927
# Epoch 18/1000
# 52/52 [==============================] - 10s 185ms/step - loss: 0.
# Epoch 40/1000
# 52/52 [==============================] - 12s 222ms/step - loss: 0.1710 - val_loss: 4.1281
# Epoch 41/1000
# 52/52 [==============================] - 12s 223ms/step - loss: 0.1534 - val_loss: 4.5950
# Epoch 42/1000
# 52/52 [==============================] - 12s 232ms/step - loss: 0.1425 - val_loss: 2.9328
# Epoch 43/1000
# 52/52 [==============================] - 13s 256ms/step - loss: 0.1352 - val_loss: 2.3584
# Epoch 44/1000
# 52/52 [==============================] - 14s 261ms/step - loss: 0.1274 - val_loss: 4.1874
# Epoch 45/1000
# 52/52 [==============================] - 14s 262ms/step - loss: 0.1321 - val_loss: 3.8230
# Epoch 46/1000
# 52/52 [==============================] - 13s 256ms/step - loss: 0.1144 - val_loss: 3.3027
# Epoch 47/1000
# 52/52 [==============================] - 12s 235ms/step - loss: 0.1163 - val_loss: 3.2691
# Epoch 48/1000
# 52/52 [==============================] - 12s 230ms/step - loss: 0.1087 - val_loss: 3.0560
# Epoch 49/1000
# 52/52 [==============================] - 12s 232ms/step - loss: 0.1009 - val_loss: 3.7742
# Epoch 50/1000
# 52/52 [==============================] - 12s 231ms/step - loss: 0.0943 - val_loss: 4.1958
# Epoch 51/1000
# 52/52 [==============================] - 12s 229ms/step - loss: 0.0930 - val_loss: 4.2342
# Epoch 52/1000
# 52/52 [==============================] - 12s 224ms/step - loss: 0.0910 - val_loss: 5.5654
# Epoch 53/1000
# 52/52 [==============================] - 12s 227ms/step - loss: 0.0920 - val_loss: 3.0542
# Epoch 54/1000
# 52/52 [==============================] - 12s 227ms/step - loss: 0.0784 - val_loss: 3.5125
# Epoch 55/1000
# 52/52 [==============================] - 12s 223ms/step - loss: 0.0924 - val_loss: 5.7497
# Epoch 56/1000
# 52/52 [==============================] - 11s 221ms/step - loss: 0.0827 - val_loss: 4.8955
# Epoch 57/1000
# 52/52 [==============================] - 12s 225ms/step - loss: 0.0750 - val_loss: 4.2700
# Epoch 58/1000
# 52/52 [==============================] - 12s 226ms/step - loss: 0.0740 - val_loss: 4.8165
# Epoch 59/1000
# 52/52 [==============================] - 12s 223ms/step - loss: 0.0674 - val_loss: 4.6751
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 130ms/step
# Feature: NVDA - RMSE: 1.617865391446909
# La médiane des prédictions est meilleure pour l'indice NVDA. RMSE: 1.428639137011658
# Entraînement des modèles de réseau neuronal terminé.

# %% [markdown]
# #### Modèle XGBoost:

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    # Si les données sont une liste ou un tableau 1D, les convertir en DataFrame
    if type(data) is list or len(data.shape) == 1:
        df = pd.DataFrame(data)
        n_vars = 1
    else:
        df = pd.DataFrame(data)
        n_vars = data.shape[1]
    cols, names = list(), list()
    # Séquence d'entrée (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # Séquence de prévision (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # Concaténer le tout
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # Supprimer les lignes avec des valeurs NaN
    if dropnan:
        agg.dropna(inplace=True)
    return agg

def recursive_prediction_xgb(model, initial_input, steps):
    current_input = np.array(initial_input)
    predictions = []
    for _ in range(steps):
        predicted_values = model.predict(current_input.reshape(1, -1))
        predictions.append(predicted_values)
        current_input = np.roll(current_input, -1)
        current_input[-1:] = predicted_values
    return np.array(predictions)

# %%
# Dictionnaires pour stocker les modèles XGBoost et leurs performances
xgb_models = {}
mse_xgb = {}
recursive_preds_xgb = {}

for index_name in final_df.columns.get_level_values(0).unique():
    
    # Sélectionner look_back optimal
    best_params = best_params_per_feature[index_name]
    look_back = best_params['look_back']
    
    # Préparer les données pour XGBoost
    # Créer un indexeur
    idx = pd.IndexSlice

    # Utiliser cet indexeur pour récupérer les données
    values = scaled_data_df.filter(like=index_name, axis=1).values
    data = series_to_supervised(values, look_back, 1)
    train = data.iloc[:train_size, :]
    test = data.iloc[train_size:, :]
    # Diviser en entrées et sorties
    
    X_train, y_train = train.iloc[:, :-1].values, train.iloc[:, -1].values
    X_test, y_test = test.iloc[:, :-1].values, test.iloc[:, -1].values
    
    # Modèle XGBoost
    model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=200)
    model.fit(X_train, y_train)
    
    # Prédictions
    initial_input = X_test[0]
    predictions = recursive_prediction_xgb(model, initial_input, len(y_test))
    
    for idx, feature_name in enumerate(['Close']):
        scaler_key = (index_name, feature_name)  # Créer la clé pour accéder au bon scaler dans le dictionnaire
        feature_scaler = scalers_dict[scaler_key]  # Récupérer le scaler correspondant
    
        # Inversez la mise à l'échelle

        inverse_predictions = feature_scaler.inverse_transform(np.array(predictions).reshape(-1, 1))
        inverse_real_values = feature_scaler.inverse_transform(y_test.reshape(-1, 1))
        
        # Appliquer le filtre gaussien
        sigma = 5
        smoothed_values_test = gaussian_filter1d(y_test, sigma)
        smoothed_values = gaussian_filter1d(y_test, sigma)
        smoothed_values_test = feature_scaler.inverse_transform(smoothed_values_test.reshape(-1, 1))
        # Afficher les graphiques
        plt.figure(figsize=(14,7))

        # Tracez les valeurs réelles
        plt.plot(inverse_real_values, label='Real Values', color='blue')
        
        plt.plot(smoothed_values_test, label='Smoothed Real Close Values', color='green')

        # Tracez les prédictions
        plt.plot(inverse_predictions, label='Predicted Values', color='red', linestyle='--')

        plt.title(f"XGBoost - Predictions Close vs Real Close values for {index_name}")
        plt.legend()
        plt.show()

        # Évaluer le modèle
        rmse = weighted_rmse(smoothed_values, np.array(predictions), len(smoothed_values))

        # Stocker le modèle et sa performance
        xgb_models[scaler_key] = model
        mse_xgb[scaler_key] = rmse
        recursive_preds_xgb[scaler_key] = inverse_predictions
        print(f"Feature: {index_name} - RMSE: {rmse}")

print("Entraînement des modèles XGBoost terminé.")
# Out:
# Feature: NG_F - RMSE: 0.0577051704908937
# Feature: NVDA - RMSE: 1.7223274558252395
# Entraînement des modèles XGBoost terminé.

# %% [markdown]
# #### Modèle SARIMA:

# %%
warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", "Non-invertible starting MA parameters found")
warnings.filterwarnings("ignore", "Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.")
"""# Dictionnaires pour stocker les modèles SARIMA et leurs performances
sarima_models = {}
mse_sarima = {}
recursive_preds_sarima = {}

for index_name in final_df.columns.get_level_values(0).unique():
    def objective_sarima(trial):
        # Paramètres à optimiser
        p = trial.suggest_int('p', 0, 5)
        d = trial.suggest_int('d', 0, 1)
        q = trial.suggest_int('q', 0, 4)
        P = trial.suggest_int('P', 0, 5)
        D = trial.suggest_int('D', 0, 1)
        Q = trial.suggest_int('Q', 0, 4)
        s = trial.suggest_int('s', 2, 12)  # saisonnalité

        # Validation des hyperparamètres
        if p == P:
            return float('inf')  # retourne une valeur infinie pour indiquer un mauvais essai

        try:
            # Création du modèle SARIMA
            sarima = SARIMAX(y_train, order=(p, d, q), seasonal_order=(P, D, Q, s))
            sarima_fit = sarima.fit(disp=False, maxiter=300, method='bfgs')

            # Prédictions
            predictions = sarima_fit.forecast(steps=len(y_test))
            
            if not np.std(predictions) > 1e-3:
                return float('inf')  # Rejeter le modèle si les prédictions sont constantes
            
            smoothed_values_test = gaussian_filter1d(y_test, sigma)

            # Calcul de la RMSE
            rmse = weighted_rmse(smoothed_values_test, predictions, len(smoothed_values_test))

            return rmse

        except Exception as e:  # Attrape toutes les exceptions, y compris les problèmes de convergence ou les erreurs de spécification du modèle
            return float('inf')  # retourne une valeur infinie pour indiquer un mauvais essai

    # Sélectionner look_back optimal
    best_params = best_params_per_feature[index_name]
    look_back = best_params['look_back']
    
    # Préparer les données pour XGBoost
    # Créer un indexeur
    idx = pd.IndexSlice

    # Utiliser cet indexeur pour récupérer les données
    values = scaled_data_df.filter(like=index_name, axis=1).values
    data = series_to_supervised(values, look_back, 1)
    train = data.iloc[:train_size, :]
    test = data.iloc[train_size:, :]
    # Diviser en entrées et sorties
    
    X_train, y_train = train.iloc[:, :-1].values, train.iloc[:, -1].values
    X_test, y_test = test.iloc[:, :-1].values, test.iloc[:, -1].values
    
    
    # Création d'une étude Optuna
    study_sarima = optuna.create_study(direction='minimize')
    study_sarima.optimize(objective_sarima, n_trials=50)
    
    best_params = study_sarima.best_params
    best_rmse = study_sarima.best_value

    # Modèle SARIMA avec les meilleurs hyperparamètres
    best_model = SARIMAX(y_train, 
                          order=(best_params['p'], best_params['d'], best_params['q']), 
                          seasonal_order=(best_params['P'], best_params['D'], best_params['Q'], best_params['s']))
    best_model_fit = best_model.fit(disp=False, maxiter=200, method='bfgs')
    
    # Meilleures prédictions
    best_predictions = best_model_fit.forecast(steps=len(y_test))
    
    for idx, feature_name in enumerate(['Close']):
        scaler_key = (index_name, feature_name)  # Créer la clé pour accéder au bon scaler dans le dictionnaire
        feature_scaler = scalers_dict[scaler_key]  # Récupérer le scaler correspondant
        
        smoothed_values_test = feature_scaler.inverse_transform(smoothed_values_test.reshape(-1, 1))
    
        # Inversez la mise à l'échelle

        inverse_predictions = feature_scaler.inverse_transform(np.array(best_predictions).reshape(-1, 1))
        inverse_real_values = feature_scaler.inverse_transform(y_test.reshape(-1, 1))
        
        
        # Appliquer le filtre gaussien
        sigma = 5
        smoothed_values_test = gaussian_filter1d(y_test, sigma)
        smoothed_values = gaussian_filter1d(y_test, sigma)
        smoothed_values_test = feature_scaler.inverse_transform(smoothed_values_test.reshape(-1, 1))
        
        # Affichage des graphiques
        plt.figure(figsize=(14,7))
        plt.plot(inverse_real_values, label='Real Values', color='blue')
        plt.plot(smoothed_values_test, label='Smoothed Real Close Values', color='green')
        plt.plot(inverse_predictions, label='Predicted Values', color='red', linestyle='--')
        plt.title(f"SARIMA - Best Predictions vs Real values for {index_name}")
        plt.legend()
        plt.show()

        # Stocker le modèle et sa performance
        sarima_models[scaler_key] = best_model
        mse_sarima[scaler_key] = best_rmse
        recursive_preds_sarima[scaler_key] = inverse_predictions

        print(f"Feature: {index_name} - Best RMSE: {best_rmse}")
        
print("Entraînement des modèles SARIMA terminé.")
"""
print("SARIMA passé")
# Out:
# SARIMA passé

# %% [markdown]
# ### Choix du modèle par features

# %%
features_choice_df = pd.DataFrame({"GRU": mse_gru})

best_model_per_feature = features_choice_df.idxmin(axis=1).to_frame(name='Best Model')
best_model_per_feature['MSE'] = features_choice_df.min(axis=1)


print(best_model_per_feature)
# Out:
#            Best Model       MSE
# NG_F Close        GRU  0.334176
# NVDA Close        GRU  1.428639

# %% [markdown]
# ### Filtrage : comparaison avec un modèle naif

# %% [markdown]
# Ce n'est parce que un modèle est meilleurs que les autres qu'il est réellement pertinant, la comparaison avec un modèle naif/simpliste indiquera si le modèle est réelement performant (et pas seulement par rapport aux autres)

# %%
# Créer un dictionnaire avec les données de test pour chaque feature
test_data_dict = {}
for feature in scaled_data_df.columns:
    test_data_dict[feature] = test_data[feature]
    
# Dictionnaire pour regrouper toutes les prédictions récursives
all_recursive_preds = {
    'GRU': recursive_preds_gru,
}

def naive_recursive_forecast(series, steps):
    """Génère des prédictions récursives en utilisant la dernière valeur connue pour `steps` prédictions."""
    predictions = [series[-1]]  # on commence avec la dernière observation
    for _ in range(steps-1):
        predictions.append(predictions[-1])
    return np.array(predictions)

mse_naive_recursive_dict = {}

for index_name in final_df.columns.get_level_values(0).unique():
    
    # Récupérer les valeurs réelles de l'indice spécifique
    actual_values = test_data_dict[(index_name, 'Close')].values[1:]
    
    # Générer des prédictions naïves pour l'indice spécifique
    naive_predictions = naive_recursive_forecast(test_data_dict[(index_name, 'Close')].values[:-1], len(actual_values))
    
    # Calculer le MSE pour ces prédictions naïves
    mse_naive_recursive = mean_squared_error(actual_values, naive_predictions)
    
    # Stocker ce MSE dans le dictionnaire
    mse_naive_recursive_dict[index_name] = mse_naive_recursive
    
    # Récupérer les valeurs réelles, les prédictions du modèle et les prédictions naïves
    best_model_name = best_model_per_feature.loc[(index_name, 'Close'), 'Best Model']
    best_model_predictions = all_recursive_preds[best_model_name][(index_name, 'Close')]
    
    actual_values = data.values
    naive_predictions = naive_recursive_forecast(data.values[:-1], len(actual_values))

# Comparer les MSE des modèles et des prévisions naïves récursives
comparison_recursive_dict = {}
for feature, row in best_model_per_feature.iterrows():
    comparison_recursive_dict[feature] = {
        'Model MSE': row['MSE'],
        'Naive Recursive MSE': mse_naive_recursive_dict[feature[0]],
        'Model is Better': row['MSE'] < mse_naive_recursive_dict[feature[0]]
    }

comparison_recursive_dict
# Out:
# {('NG_F', 'Close'): {'Model MSE': 0.3341761581503885,
#   'Naive Recursive MSE': 0.7615035197546122,
#   'Model is Better': True},
#  ('NVDA', 'Close'): {'Model MSE': 1.428639137011658,
#   'Naive Recursive MSE': 25.579940538957747,
#   'Model is Better': True}}

# %% [markdown]
# ### Conclusion sur les features finales

# %%
# Vérifier pour quelles features le modèle naïf est meilleur
naive_better_features = [feature for feature, values in comparison_recursive_dict.items() if not values['Model is Better']]

# Afficher un message d'avertissement pour ces features
if naive_better_features:
    print("Avertissement : Pour les features suivantes, le modèle naïf a performé mieux que le modèle choisi :")
    for feature in naive_better_features:
        print(f"- {feature}")

# %% [markdown]
# # Modèle final : basé sur les précédentes features

# %% [markdown]
# #### Préparation des données

# %%
final_features  = []
for model_type in all_recursive_preds:
    for feature in comparison_recursive_dict:
        print("for : " + str(feature) + "/" + str(model_type) + ":" + str(all_recursive_preds[model_type][feature][0]))
        
for feature in comparison_recursive_dict:
    final_features.append(feature)

# Initialiser le dictionnaire pour stocker les scalers pour chaque feature
final_scalers = {}
print(final_features)
# Mettre à l'échelle les données pour chaque feature
final_features_with_sp500 = final_features + [('GSPC', 'Open')] + [('GSPC', 'Close')]
final_combined_data = combined_data[final_features_with_sp500].copy()

print("Combined data shape:", combined_data.shape)

for feature in final_features:
    scaler = MinMaxScaler()
    final_combined_data[feature] = scaler.fit_transform(final_combined_data[feature].values.reshape(-1, 1))
    final_scalers[feature] = scaler

# Mettre à l'échelle le SP500
sp500_scaler = RobustScaler()
final_combined_data[('GSPC', 'Open')] = sp500_scaler.fit_transform(final_combined_data[('GSPC', 'Open')].values.reshape(-1, 1))
final_combined_data[('GSPC', 'Close')] = sp500_scaler.fit_transform(final_combined_data[('GSPC', 'Close')].values.reshape(-1, 1))

final_combined_data.tail()
# Out:
# for : ('NG_F', 'Close')/GRU:7.5042534
# for : ('NVDA', 'Close')/GRU:181.13963
# for : ('NG_F', 'Close')/XGBoost:[2.612946]
# for : ('NVDA', 'Close')/XGBoost:[225.5276]
# [('NG_F', 'Close'), ('NVDA', 'Close')]
# Combined data shape: (3680, 152)
#                 NG_F      NVDA      GSPC
#                Close     Close      Open     Close
# Date
# 2023-09-27  0.085346  0.860237  1.609012  1.602294
# 2023-09-28  0.098470  0.872840  1.600493  1.618837
# 2023-10-10  0.130157  0.927815  1.646501  1.657281
# 2023-10-11  0.129795  0.948271  1.664117  1.669568
# 2023-10-13  0.119571  0.920976  1.660113  1.637277

# %% [markdown]
# # Etudes des paramètres optimaux du modèle final

# %%
early_stopping = EarlyStopping(monitor='val_mean_directional_accuracy', mode='max', patience=10, restore_best_weights=True)

def mean_directional_accuracy(y_true, y_pred):
    # Obtenir la forme du tenseur y_true (ou y_pred, de même forme)
    y_shape = K.shape(y_true)

    # Calculer le nombre d'échantillons dans ce lot
    batch_size = y_shape[0]

    # Calculer le nombre de blocs de 10 que nous pouvons avoir
    num_blocks = batch_size // 10

    # Calculer le nombre d'échantillons à garder pour avoir un multiple de 10
    keep_samples = num_blocks * 10

    # Tronquer les tenseurs pour avoir un multiple de 10
    y_true = y_true[:keep_samples]
    y_pred = y_pred[:keep_samples]

    # Si keep_samples est 0, retourner 0 comme métrique
    if keep_samples == 0:
        return K.constant(0, dtype='float32')

    # Réorganiser en blocs de 10
    y_true_reshaped = K.reshape(y_true, (-1, 10))
    y_pred_reshaped = K.reshape(y_pred, (-1, 10))

    # Calculer la différence entre le premier et le dernier élément de chaque bloc
    true_diff = y_true_reshaped[:, -1] - y_true_reshaped[:, 0]
    pred_diff = y_pred_reshaped[:, -1] - y_pred_reshaped[:, 0]

    # Comparer les signes
    matches = K.equal(K.sign(true_diff), K.sign(pred_diff))

    # Calculer la précision directionnelle moyenne
    accuracy = K.mean(K.cast(matches, dtype='float32'))

    return accuracy

def create_sequences(data, look_back=100):
    X, y = [], []
    total_data_points = len(data) // 2 * 2  # Pour s'assurer que nous avons un nombre pair de jours à considérer
    
    for i in range(look_back, total_data_points - 1, 1):  # On avance de un en un pour prendre en compte chaque jour
        sequence_data_open = []
        sequence_data_close = []

        # Ajouter les valeurs d'ouverture et de clôture, alternées
        for j in range(i - look_back, i):
            sequence_data_open.append([data[j, -2]])  # Valeur d'ouverture
            sequence_data_close.append([data[j, -1]])  # Valeur de clôture

        # Séquence pour les autres features
        other_features_seq = data[i - look_back:i, :-2]

        # Double chaque valeur de clôture prédite pour les autres features
        other_features_seq_doubled_open = np.repeat(other_features_seq, 1, axis=0)
        other_features_seq_doubled_close = np.repeat(other_features_seq, 1, axis=0)

        # Combinez les séquences
        combined_seq_open = np.hstack([other_features_seq_doubled_open, sequence_data_open])
        combined_seq_close = np.hstack([other_features_seq_doubled_close, sequence_data_close])

        X.append(combined_seq_open)  # Remodeler pour avoir look_back x (nombre de features - 1)
        y.append(data[i, -1])  # Clôture du jour i

        X.append(combined_seq_close)  # Remodeler pour avoir look_back x (nombre de features - 1)
        y.append(data[i + 1, -2])  # Ouverture du jour i+1

    return np.array(X), np.array(y)

def create_model(num_layers, layer_type, units_per_layer, dropout_per_layer, input_shape, use_conv1d , conv1d_filters ,conv1d_kernel_size ,use_residual_connection, attention_layer, l1_reg, l2_reg):
    inputs = Input(shape=input_shape)
    x = inputs
    if use_conv1d:
        x = Conv1D(conv1d_filters, kernel_size=conv1d_kernel_size, activation='relu')(x)
    if layer_type[0] == "GRU":
        x = Bidirectional(GRU(units_per_layer[0], return_sequences=True, kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg)))(x)
    elif layer_type[0] == "LSTM":
        x = Bidirectional(LSTM(units_per_layer[0], return_sequences=True, kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg)))(x)
    x = Dropout(dropout_per_layer[0])(x)
    for i in range(1, num_layers):
        if use_residual_connection and units_per_layer[i] == units_per_layer[i-1]:
            x_res = x
        if layer_type[i] == "GRU":
            x = Bidirectional(GRU(units_per_layer[i], return_sequences=True, kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg)))(x)
        elif layer_type[i] == "LSTM":
            x = Bidirectional(LSTM(units_per_layer[i], return_sequences=True, kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg)))(x)
        x = Dropout(dropout_per_layer[i])(x)
        if attention_layer:
            x = Attention(use_scale=True)([x, x])
        if use_residual_connection and units_per_layer[i] == units_per_layer[i-1]:
            x = Add()([x, x_res])
    if layer_type[num_layers-1] == "GRU":
        x = Bidirectional(GRU(units_per_layer[num_layers-1]))(x)
    elif layer_type[num_layers-1] == "LSTM":
        x = Bidirectional(LSTM(units_per_layer[num_layers-1]))(x)
    x = Dense(25)(x)
    outputs = Dense(1)(x)
    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=[mean_directional_accuracy])
    return model

# Fonction pour réaliser une prédiction récursive avec le modèle final
def recursive_prediction_final_model(model, initial_input, steps, best_model_per_feature, final_scalers, look_back):
    recursive_predictions = []
    current_input = initial_input.copy()

    for step in range(steps):
        # Utilisez les X derniers jours (qu'ils soient réels ou prédits) pour faire la prédiction
        input_for_prediction = current_input[-look_back:]
        
        # Prédire la prochaine valeur du SP500 en utilisant le modèle final
        predicted_sp500_values = model.predict(input_for_prediction.reshape(1, look_back, input_for_prediction.shape[1]), verbose=0)
        recursive_predictions.append(predicted_sp500_values)

        # Mettez à jour l'entrée pour la prochaine prédiction en utilisant les meilleurs modèles pour chaque caractéristique
        new_input_row = []
        for feature in final_features:
            model_type = best_model_per_feature['Best Model'][feature]
            predicted_feature_value = all_recursive_preds[model_type][feature][step//2]

            # Mettez à l'échelle la caractéristique prédite
            scaled_feature_prediction = final_scalers[feature].transform(np.array(predicted_feature_value).reshape(-1, 1))
            new_input_row.append(scaled_feature_prediction[0][0])

        # Utilisez deux fois la valeur de clôture prédite pour les autres indices comme entrée
        #new_input_row = [item for item in new_input_row for _ in range(2)]

        # Ajouter les valeurs prédites ajustées pour le S&P 500
        new_input_row.append(predicted_sp500_values[0, 0])

        # Mettez à jour l'entrée pour la prochaine prédiction
        current_input = np.vstack([current_input[1:], np.array(new_input_row)])

    return np.array(recursive_predictions)

def objective(trial):

    # Espace de recherche
    ###############################################################################################
    look_back = trial.suggest_int('look_back', int(test_size/3), int(test_size/2) - 1)
    num_layers = trial.suggest_int('num_layers', 3, 9)
    layer_type = [trial.suggest_categorical(f'layer_type_{i}', ['LSTM', 'GRU']) for i in range(num_layers)]
    units_per_layer = [trial.suggest_int(f'units_power_{i}', 7, 9) for i in range(num_layers)]
    units_per_layer = [2 ** power for power in units_per_layer]
    dropout_per_layer = [trial.suggest_float(f'dropout_{i}', 0.1, 0.3) for i in range(num_layers)]
    use_residual_connection = trial.suggest_categorical('use_residual_connection', [True, False])
    attention_layer = trial.suggest_categorical('use_attention_layer', [True, False])
    use_conv1d = trial.suggest_categorical('use_conv1d', [False, True])
    if use_conv1d:
        conv1d_filters = trial.suggest_int('conv1d_filters', 5, 7)
        conv1d_filters = 2 ** conv1d_filters
        conv1d_kernel_size = trial.suggest_int('conv1d_kernel_size', 3, 7)
    l1_reg = trial.suggest_float('l1_reg', 1e-5, 1e-1, log=True)
    l2_reg = trial.suggest_float('l2_reg', 1e-5, 1e-1, log=True)
    ################################################################################################
    
    # Créez des séquences en utilisant look_back
    X_train, y_train = create_sequences(final_combined_data.iloc[:train_size].values, look_back)
    X_test, y_test = create_sequences(final_combined_data.iloc[train_size:].values, look_back)
    
    n_splits = 5  # Nombre de splits
    tscv = TimeSeriesSplit(n_splits=n_splits)
    
    val_loss_list = []  # Liste pour stocker la val_loss de chaque split
        
    for train_index, val_index in tscv.split(X_train):
        X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]
        
        if use_conv1d:
            model = create_model(num_layers, layer_type, units_per_layer, dropout_per_layer, ((look_back), (len(reduced_df.columns) + 1)), use_conv1d, conv1d_filters, conv1d_kernel_size, use_residual_connection, attention_layer, l1_reg, l2_reg)
        else:
            conv1d_filters = 36
            conv1d_kernel_size = 5
            model = create_model(num_layers, layer_type, units_per_layer, dropout_per_layer, ((look_back), (len(reduced_df.columns) + 1)), use_conv1d, conv1d_filters, conv1d_kernel_size, use_residual_connection, attention_layer, l1_reg, l2_reg)

        recursive_predictions = []
        
        input_sequence = X_val_fold[0].reshape(1, look_back, len(reduced_df.columns) + 1)

        history = model.fit(X_train_fold, y_train_fold, validation_data=(X_val_fold, y_val_fold), epochs=15, batch_size=32, verbose=0, callbacks=[early_stopping])
        
        # Obtenez la val_loss du dernier epoch
        last_val_loss = history.history['val_loss'][-1]
        val_loss_list.append(last_val_loss)
    
    mean_val_loss = np.mean(val_loss_list)  # Moyenne des val_loss sur tous les plis
    
    initial_input = X_val_fold[0]
    recursive_predictions = recursive_prediction_final_model(model, initial_input, look_back, best_model_per_feature, final_scalers, look_back) #prédictions que sur le dernier pli
    if not np.std(recursive_predictions[:, 0][:, 0]) > 1e-3:
        return float('inf')  # Rejeter le modèle si les prédictions sont constantes
    return mean_val_loss

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)

best_params_final = study.best_params
top_5_trials = sorted(study.trials, key=lambda trial: trial.value)[:5]

# Affichage des résultats
print('Number of finished trials: ', len(study.trials))
for i, trial in enumerate(top_5_trials):
    print(f'Rank {i+1} - Value: {trial.value}, Params: {trial.params}')
# Out:
# [I 2023-10-19 02:39:35,376] A new study created in memory with name: no-name-03d5f276-dc79-41c5-ad11-a5c4eb2d600a
# [I 2023-10-19 03:12:08,175] Trial 0 finished with value: inf and parameters: {'look_back': 90, 'num_layers': 9, 'layer_type_0': 'GRU', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'LSTM', 'layer_type_4': 'LSTM', 'layer_type_5': 'LSTM', 'layer_type_6': 'GRU', 'layer_type_7': 'LSTM', 'layer_type_8': 'GRU', 'units_power_0': 7, 'units_power_1': 8, 'units_power_2': 8, 'units_power_3': 9, 'units_power_4': 9, 'units_power_5': 7, 'units_power_6': 8, 'units_power_7': 8, 'units_power_8': 9, 'dropout_0': 0.29014795633645146, 'dropout_1': 0.1708893385200279, 'dropout_2': 0.2843479733936827, 'dropout_3': 0.20822486022300063, 'dropout_4': 0.2758757535838079, 'dropout_5': 0.2160205064123154, 'dropout_6': 0.19982674308994175, 'dropout_7': 0.10172421403817909, 'dropout_8': 0.12938204604485132, 'use_residual_connection': False, 'use_attention_layer': False, 'use_conv1d': False, 'l1_reg': 0.00011056655553674779, 'l2_reg': 0.0007769396511217296}. Best is trial 0 with value: inf.
# [I 2023-10-19 03:49:10,667] Trial 1 finished with value: inf and parameters: {'look_back': 123, 'num_layers': 8, 'layer_type_0': 'LSTM', 'layer_type_1': 'GRU', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'GRU', 'layer_type_5': 'LSTM', 'layer_type_6': 'GRU', 'layer_type_7': 'LSTM', 'units_power_0': 9, 'units_power_1': 9, 'units_power_2': 8, 'units_power_3': 8, 'units_power_4': 7, 'units_power_5': 7, 'units_power_6': 9, 'units_power_7': 8, 'dropout_0': 0.23818284501475592, 'dropout_1': 0.12683703486517062, 'dropout_2': 0.23959695195670278, 'dropout_3': 0.2542810426793015, 'dropout_4': 0.25658639374689285, 'dropout_5': 0.19872407246610924, 'dropout_6': 0.1561264102424354, 'dropout_7': 0.1849520838690374, 'use_residual_connection': False, 'use_attention_layer': True, 'use_conv1d': False, 'l1_reg': 0.05449931802374911, 'l2_reg': 0.0007729361311291533}. Best is trial 0 with value: inf.
# [I 2023-10-19 04:10:06,952] Trial 2 finished with value: 0.26033771932125094 and parameters: {'look_back': 92, 'num_layers': 6, 'layer_type_0': 'GRU', 'layer_type_1': 'LSTM', 'layer_type_2': 'GRU', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'layer_type_5': 'GRU', 'units_power_0': 8, 'units_power_1': 7, 'units_power_2': 7, 'units_power_3': 7, 'units_power_4': 9, 'units_power_5': 9, 'dropout_0': 0.18556197731314902, 'dropout_1': 0.11080652065636186, 'dropout_2': 0.28460148179844125, 'dropout_3': 0.23146799223481201, 'dropout_4': 0.2901593452915323, 'dropout_5': 0.10024727224993396, 'use_residual_connection': False, 'use_attention_layer': False, 'use_conv1d': True, 'conv1d_filters': 7, 'conv1d_kernel_size': 6, 'l1_reg': 5.0526707219034397e-05, 'l2_reg': 4.247787108994609e-05}. Best is trial 2 with value: 0.26033771932125094.
# [I 2023-10-19 04:35:22,688] Trial 3 finished with value: 0.20482073575258256 and parameters: {'look_back': 123, 'num_layers': 4, 'layer_type_0': 'GRU', 'layer_type_1': 'LSTM', 'layer_type_2': 'LSTM', 'layer_type_3': 'LSTM', 'units_power_0': 8, 'units_power_1': 9, 'units_power_2': 9, 'units_power_3': 9, 'dropout_0': 0.23335987825996093, 'dropout_1': 0.2575704436502025, 'dropout_2': 0.10274687492150475, 'dropout_3': 0.21376350689727838, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': True, 'conv1d_filters': 7, 'conv1d_kernel_size': 7, 'l1_reg': 6.226648464497764e-05, 'l2_reg': 0.0004818826794402588}. Best is trial 3 with value: 0.20482073575258256.
# [I 2023-10-19 05:06:18,264] Trial 4 finished with value: inf and parameters: {'look_back': 102, 'num_layers': 9, 'layer_type_0': 'LSTM', 'layer_type_1': 'LSTM', 'layer_type_2': 'GRU', 'layer_type_3': 'LSTM', 'layer_type_4': 'GRU', 'layer_type_5': 'LSTM', 'layer_type_6': 'LSTM', 'layer_type_7': 'LSTM', 'layer_type_8': 'LSTM', 'units_power_0': 9, 'units_power_1': 7, 'units_power_2': 7, 'units_power_3': 7, 'units_power_4': 8, 'units_power_5': 9, 'units_power_6': 8, 'units_power_7': 8, 'units_power_8': 7, 'dropout_0': 0.25391205473781187, 'dropout_1': 0.24901623419798483, 'dropout_2': 0.16036046293644762, 'dropout_3': 0.19505632082488886, 'dropout_4': 0.12233695891845085, 'dropout_5': 0.24511086854681638, 'dropout_6': 0.1871097078844512, 'dropout_7': 0.1458113267914773, 'dropout_8': 0.1802883980554287, 'use_residual_connection': False, 'use_attention_layer': False, 'use_conv1d': False, 'l1_reg': 0.012782531783620672, 'l2_reg': 0.018130047314602507}. Best is trial 3 with value: 0.20482073575258256.
# [I 2023-10-19 05:17:02,112] Trial 5 finished with value: inf and parameters: {'look_back': 89, 'num_layers': 3, 'layer_type_0': 'LSTM', 'layer_type_1': 'GRU', 'layer_type_2': 'GRU', 'units_power_0': 7, 'units_power_1': 7, 'units_power_2': 8, 'dropout_0': 0.15889994068895413, 'dropout_1': 0.1652760984279423, 'dropout_2': 0.26146790500477773, 'use_residual_connection': False, 'use_attention_layer': False, 'use_conv1d': False, 'l1_reg': 0.016676373025119002, 'l2_reg': 0.053101979477831684}. Best is trial 3 with value: 0.20482073575258256.
# [I 2023-10-19 05:32:35,112] Trial 6 finished with value: inf and parameters: {'look_back': 90, 'num_layers': 4, 'layer_type_0': 'GRU', 'layer_type_1': 'LSTM', 'layer_type_2': 'GRU', 'layer_type_3': 'LSTM', 'units_power_0': 7, 'units_power_1': 7, 'units_power_2': 8, 'units_power_3': 9, 'dropout_0': 0.24711784044762142, 'dropout_1': 0.20070797591786116, 'dropout_2': 0.1019556309563186, 'dropout_3': 0.10248682774477241, 'use_residual_connection': False, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 5, 'conv1d_kernel_size': 5, 'l1_reg': 0.006998908012187238, 'l2_reg': 0.018348535038884922}. Best is trial 3 with value: 0.20482073575258256.
# [I 2023-10-19 05:55:21,285] Trial 7 finished with value: inf and parameters: {'look_back': 102, 'num_layers': 5, 'layer_type_0': 'LSTM', 'layer_type_1': 'GRU', 'layer_type_2': 'GRU', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'units_power_0': 8, 'units_power_1': 8, 'units_power_2':
 'layer_type_0': 'GRU', 'layer_type_1': 'LSTM', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'units_power_0': 8, 'units_power_1': 9, 'units_power_2': 9, 'units_power_3': 8, 'dropout_0': 0.2816340498391643, 'dropout_1': 0.2973580301472313, 'dropout_2': 0.1821359390163149, 'dropout_3': 0.2983042662961074, 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 7, 'conv1d_kernel_size': 7, 'l1_reg': 1.0294339556639859e-05, 'l2_reg': 0.00013054481752923012}. Best is trial 11 with value: 0.1448456861078739.
# [I 2023-10-19 08:54:44,250] Trial 14 finished with value: 2.5038979053497314 and parameters: {'look_back': 116, 'num_layers': 6, 'layer_type_0': 'GRU', 'layer_type_1': 'LSTM', 'layer_type_2': 'LSTM', 'layer_type_3': 'LSTM', 'layer_type_4': 'GRU', 'layer_type_5': 'GRU', 'units_power_0': 9, 'units_power_1': 9, 'units_power_2': 9, 'units_power_3': 8, 'units_power_4': 8, 'units_power_5': 8, 'dropout_0': 0.2758051554288908, 'dropout_1': 0.2733231766408532, 'dropout_2': 0.15088693325177388, 'dropout_3': 0.16802617537907727, 'dropout_4': 0.10186564866208585, 'dropout_5': 0.1017276167583724, 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 6, 'conv1d_kernel_size': 3, 'l1_reg': 0.0008547011633136686, 'l2_reg': 1.002154371839022e-05}. Best is trial 11 with value: 0.1448456861078739.
# [I 2023-10-19 09:11:17,417] Trial 15 finished with value: 0.1335762519389391 and parameters: {'look_back': 115, 'num_layers': 3, 'layer_type_0': 'GRU', 'layer_type_1': 'LSTM', 'layer_type_2': 'LSTM', 'units_power_0': 7, 'units_power_1': 8, 'units_power_2': 9, 'dropout_0': 0.2757141360742117, 'dropout_1': 0.27573385473329537, 'dropout_2': 0.19853219048681817, 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 7, 'conv1d_kernel_size': 6, 'l1_reg': 2.512876470164744e-05, 'l2_reg': 0.0024354853411154135}. Best is trial 15 with value: 0.1335762519389391.
# [I 2023-10-19 09:30:17,089] Trial 16 finished with value: 0.25078495517373084 and parameters: {'look_back': 111, 'num_layers': 5, 'layer_type_0': 'GRU', 'layer_type_1': 'LSTM', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'LSTM', 'units_power_0': 7, 'units_power_1': 8, 'units_power_2': 9, 'units_power_3': 7, 'units_power_4': 7, 'dropout_0': 0.2702577781659148, 'dropout_1': 0.26562242004062825, 'dropout_2': 0.19797570678059556, 'dropout_3': 0.11061980222952773, 'dropout_4': 0.1610661606522419, 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 7, 'conv1d_kernel_size': 6, 'l1_reg': 3.199597094432282e-05, 'l2_reg': 0.002681727541060289}. Best is trial 15 with value: 0.1335762519389391.
# [I 2023-10-19 09:52:10,706] Trial 17 finished with value: 0.3195363998413086 and parameters: {'look_back': 120, 'num_layers': 5, 'layer_type_0': 'GRU', 'layer_type_1': 'LSTM', 'layer_type_2': 'LSTM', 'layer_type_3': 'LSTM', 'layer_type_4': 'GRU', 'units_power_0': 7, 'units_power_1': 8, 'units_power_2': 7, 'units_power_3': 8, 'units_power_4': 8, 'dropout_0': 0.2145970615152924, 'dropout_1': 0.29818487114604175, 'dropout_2': 0.20849373836583224, 'dropout_3': 0.29347597852893004, 'dropout_4': 0.19863219663690246, 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 6, 'conv1d_kernel_size': 6, 'l1_reg': 0.0004043697256292103, 'l2_reg': 0.00270059153729904}. Best is trial 15 with value: 0.1335762519389391.
# [I 2023-10-19 10:21:10,342] Trial 18 finished with value: 0.4273940742015839 and parameters: {'look_back': 97, 'num_layers': 7, 'layer_type_0': 'LSTM', 'layer_type_1': 'LSTM', 'layer_type_2': 'LSTM', 'layer_type_3': 'GRU', 'layer_type_4': 'GRU', 'layer_type_5': 'GRU', 'layer_type_6': 'LSTM', 'units_power_0': 7, 'units_power_1': 8, 'units_power_2': 9, 'units_power_3': 7, 'units_power_4': 7, 'units_power_5': 8, 'units_power_6': 9, 'dropout_0': 0.2668992422406334, 'dropout_1': 0.23562189688715715, 'dropout_2': 0.14033030580398942, 'dropout_3': 0.13750886291558834, 'dropout_4': 0.1543152806330414, 'dropout_5': 0.29906305819629797, 'dropout_6': 0.2989706626267301, 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': False, 'l1_reg':
 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 5, 'conv1d_kernel_size': 3, 'l1_reg': 1.6802857826088106e-05, 'l2_reg': 0.0036882181472584975}. Best is trial 31 with value: 0.02449041549116373.
# [I 2023-10-19 16:56:11,927] Trial 45 finished with value: 0.14078864008188247 and parameters: {'look_back': 94, 'num_layers': 4, 'layer_type_0': 'GRU', 'layer_type_1': 'LSTM', 'layer_type_2': 'LSTM', 'layer_type_3': 'LSTM', 'units_power_0': 8, 'units_power_1': 8, 'units_power_2': 8, 'units_power_3': 9, 'dropout_0': 0.288458760833085, 'dropout_1': 0.2557596572340445, 'dropout_2': 0.2138653395412583, 'dropout_3': 0.20639027444816965, 'use_residual_connection': True, 'use_attention_layer': False, 'use_conv1d': True, 'conv1d_filters': 5, 'conv1d_kernel_size': 5, 'l1_reg': 3.794440597190369e-05, 'l2_reg': 0.0039846916739585125}. Best is trial 31 with value: 0.02449041549116373.
# [I 2023-10-19 17:06:40,668] Trial 46 finished with value: 0.01231810450553894 and parameters: {'look_back': 90, 'num_layers': 3, 'layer_type_0': 'GRU', 'layer_type_1': 'LSTM', 'layer_type_2': 'GRU', 'units_power_0': 8, 'units_power_1': 8, 'units_power_2': 8, 'dropout_0': 0.2290397514319651, 'dropout_1': 0.26875855941122184, 'dropout_2': 0.20798468238623902, 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 6, 'conv1d_kernel_size': 4, 'l1_reg': 1.0126336293849065e-05, 'l2_reg': 0.010370073424101012}. Best is trial 46 with value: 0.01231810450553894.
# [I 2023-10-19 17:21:39,790] Trial 47 finished with value: 0.06876469813287259 and parameters: {'look_back': 100, 'num_layers': 4, 'layer_type_0': 'GRU', 'layer_type_1': 'GRU', 'layer_type_2': 'GRU', 'layer_type_3': 'GRU', 'units_power_0': 8, 'units_power_1': 8, 'units_power_2': 8, 'units_power_3': 7, 'dropout_0': 0.2294785950352382, 'dropout_1': 0.2689193076594087, 'dropout_2': 0.22653343218113337, 'dropout_3': 0.18772597800037005, 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 6, 'conv1d_kernel_size': 4, 'l1_reg': 1.0782101116611862e-05, 'l2_reg': 0.009867665861622483}. Best is trial 46 with value: 0.01231810450553894.
# [I 2023-10-19 17:34:44,836] Trial 48 finished with value: 0.1062642615288496 and parameters: {'look_back': 89, 'num_layers': 3, 'layer_type_0': 'GRU', 'layer_type_1': 'LSTM', 'layer_type_2': 'GRU', 'units_power_0': 8, 'units_power_1': 9, 'units_power_2': 8, 'dropout_0': 0.24469563756403706, 'dropout_1': 0.2801748057119774, 'dropout_2': 0.20713300746567712, 'use_residual_connection': False, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 6, 'conv1d_kernel_size': 5, 'l1_reg': 1.404891702145071e-05, 'l2_reg': 0.00675063536031109}. Best is trial 46 with value: 0.01231810450553894.
# [I 2023-10-19 18:01:15,031] Trial 49 finished with value: 2.6148848652839662 and parameters: {'look_back': 90, 'num_layers': 8, 'layer_type_0': 'GRU', 'layer_type_1': 'LSTM', 'layer_type_2': 'GRU', 'layer_type_3': 'LSTM', 'layer_type_4': 'LSTM', 'layer_type_5': 'GRU', 'layer_type_6': 'GRU', 'layer_type_7': 'GRU', 'units_power_0': 8, 'units_power_1': 8, 'units_power_2': 8, 'units_power_3': 9, 'units_power_4': 7, 'units_power_5': 8, 'units_power_6': 8, 'units_power_7': 9, 'dropout_0': 0.18831129983297207, 'dropout_1': 0.2615743698558839, 'dropout_2': 0.22094830009898836, 'dropout_3': 0.2665196488915097, 'dropout_4': 0.1462796358717887, 'dropout_5': 0.17008706182093453, 'dropout_6': 0.2454825091317806, 'dropout_7': 0.2837954111630254, 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': False, 'l1_reg': 1.000139058257245e-05, 'l2_reg': 0.002983813993730731}. Best is trial 46 with value: 0.01231810450553894.
# Number of finished trials:  50
# Rank 1 - Value: 0.01231810450553894, Params: {'look_back': 90, 'num_layers': 3, 'layer_type_0': 'GRU', 'layer_type_1': 'LSTM', 'layer_type_2': 'GRU', 'units_power_0': 8, 'units_power_1': 8, 'units_power_2': 8, 'dropout_0': 0.2290397514319651, 'dropout_1': 0.26875855941122184, 'dropout_2': 0.20798468238623902, 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 6, 'conv1d_kernel_size': 4, 'l1_reg': 1.0126336293849065e-05, 'l2_reg': 0.010370073424101012}
# Rank 2 - Value: 0.02449041549116373, Params: {'look_back': 83, 'num_layers': 3, 'layer_type_0': 'GRU', 'layer_type_1': 'LSTM', 'layer_type_2': 'LSTM', 'units_power_0': 8, 'units_power_1': 8, 'units_power_2': 8, 'dropout_0': 0.2993049217687652, 'dropout_1': 0.24760045368086908, 'dropout_2': 0.24887930601407798, 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 5, 'conv1d_kernel_size': 4, 'l1_reg': 1.8636651918048e-05, 'l2_reg': 0.005759894826756716}
# Rank 3 - Value: 0.026366898603737355, Params: {'look_back': 83, 'num_layers': 3, 'layer_type_0': 'GRU', 'layer_type_1': 'LSTM', 'layer_type_2': 'LSTM', 'units_power_0': 8, 'units_power_1': 8, 'units_power_2': 8, 'dropout_0': 0.29866905915067044, 'dropout_1': 0.24039186743573304, 'dropout_2': 0.22054601202713536, 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 6, 'conv1d_kernel_size': 6, 'l1_reg': 2.4639181269757433e-05, 'l2_reg': 0.0022063207135411774}
# Rank 4 - Value: 0.03027438297867775, Params: {'look_back': 83, 'num_layers': 3, 'layer_type_0': 'GRU', 'layer_type_1': 'LSTM', 'layer_type_2': 'LSTM', 'units_power_0': 8, 'units_power_1': 8, 'units_power_2': 8, 'dropout_0': 0.29894921932373736, 'dropout_1': 0.2375347041966646, 'dropout_2': 0.22340696796527504, 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 6, 'conv1d_kernel_size': 6, 'l1_reg': 2.477508461694764e-05, 'l2_reg': 0.0020580732186878887}
# Rank 5 - Value: 0.03846918549388647, Params: {'look_back': 86, 'num_layers': 3, 'layer_type_0': 'GRU', 'layer_type_1': 'LSTM', 'layer_type_2': 'LSTM', 'units_power_0': 8, 'units_power_1': 8, 'units_power_2': 8, 'dropout_0': 0.29666885224812733, 'dropout_1': 0.2442953649134622, 'dropout_2': 0.23643149742640965, 'use_residual_connection': True, 'use_attention_layer': True, 'use_conv1d': True, 'conv1d_filters': 5, 'conv1d_kernel_size': 3, 'l1_reg': 1.801958397196746e-05, 'l2_reg': 0.0008625022381206897}

# %% [markdown]
# #### Création du modèle

# %%
all_predictions = []
final_close_predictions = []
final_models = []
early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)



for i, trial in enumerate(top_5_trials):
    best_params = trial.params
    
    # Créer le modèle de réseau neuronal
    final_model = create_model(
            num_layers = best_params_final['num_layers'],
            units_per_layer=[2 ** (best_params_final[f'units_power_{i}']) for i in range(int(best_params_final['num_layers']))],
            layer_type=[best_params_final[f'layer_type_{i}'] for i in range(best_params_final['num_layers'])],
            dropout_per_layer=[best_params_final[f'dropout_{i}'] for i in range(best_params_final['num_layers'])],
            input_shape=((best_params_final['look_back']), (len(reduced_df.columns) + 1)),
            use_conv1d=best_params_final['use_conv1d'],
            conv1d_filters=2 ** best_params_final.get('conv1d_filters', 0),
            conv1d_kernel_size=best_params_final.get('conv1d_kernel_size', None),
            use_residual_connection=best_params_final['use_residual_connection'],
            attention_layer=best_params_final['use_attention_layer'],
            l1_reg=best_params_final['l1_reg'],
            l2_reg=best_params_final['l2_reg']
    )
    
    #Création de séquences

    X_train_final, y_train_final = create_sequences(final_combined_data.iloc[:train_size].values, best_params_final['look_back'])
    X_test_final, y_test_final = create_sequences(final_combined_data.iloc[train_size:].values, best_params_final['look_back'])

    history = final_model.fit(
        X_train_final, y_train_final,
        validation_data=(X_test_final, y_test_final),
        epochs=1000,
        batch_size=32,
        callbacks=[early_stopping]
    )

    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.legend()
    plt.show()
    
    # Initialiser l'entrée récursive avec les dernières valeurs réelles des caractéristiques filtrées et la valeur du SP500 de la veille
    initial_input_features = final_combined_data[final_features].iloc[-(best_params_final['look_back']):].values
    initial_input_sp500_close = final_combined_data[('GSPC', 'Close')].iloc[-(best_params_final['look_back']):].values.reshape(-1, 1)
    initial_input_sp500_open = final_combined_data[('GSPC', 'Open')].iloc[-(best_params_final['look_back']):].values.reshape(-1, 1)

    # Alternance des valeurs 'Close' et 'Open'
    initial_input_sp500 = np.column_stack((initial_input_sp500_close, initial_input_sp500_open)).ravel().reshape(-1, 1)

    # Concaténer les caractéristiques et la valeur du SP500 pour former l'entrée récursive initiale
    initial_input = np.hstack([np.repeat(initial_input_features, 2, axis=0), initial_input_sp500])


    # Effectuer la prédiction récursive avec le modèle final
    last_n_real_values_sp500 = combined_data[('GSPC', 'Close')].iloc[-10-len(y_test_final):].values.flatten()
    predictions = recursive_prediction_final_model(final_model, initial_input, best_params_final['look_back'], best_model_per_feature, final_scalers, best_params_final['look_back'])
    
    # Ne conserver que les prédictions de clôture (positions impaires)
    close_predictions = predictions[1::2]  # Commence à l'index 1 et prend chaque deuxième élément à partir de là
    final_close_predictions.append(close_predictions)
    
    all_predictions.append(predictions)
    final_models.append(final_model)
# Out:
# Epoch 1/1000
# 209/209 [==============================] - 24s 89ms/step - loss: 4.5301 - mean_directional_accuracy: 0.9506 - val_loss: 0.3737 - val_mean_directional_accuracy: 0.5667
# Epoch 2/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.1592 - mean_directional_accuracy: 0.9665 - val_loss: 0.0592 - val_mean_directional_accuracy: 0.6000
# Epoch 3/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0323 - mean_directional_accuracy: 0.9697 - val_loss: 0.0235 - val_mean_directional_accuracy: 0.6000
# Epoch 4/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.0124 - mean_directional_accuracy: 0.9745 - val_loss: 0.0097 - val_mean_directional_accuracy: 0.6000
# Epoch 5/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.0072 - mean_directional_accuracy: 0.9729 - val_loss: 0.0065 - val_mean_directional_accuracy: 0.5667
# Epoch 6/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.0048 - mean_directional_accuracy: 0.9809 - val_loss: 0.0091 - val_mean_directional_accuracy: 0.6333
# Epoch 7/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0051 - mean_directional_accuracy: 0.9761 - val_loss: 0.0046 - val_mean_directional_accuracy: 0.6000
# Epoch 8/1000
# 209/209 [==============================] - 19s 93ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9697 - val_loss: 0.0049 - val_mean_directional_accuracy: 0.6000
# Epoch 9/1000
# 209/209 [==============================] - 20s 97ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9753 - val_loss: 0.0056 - val_mean_directional_accuracy: 0.6000
# Epoch 10/1000
# 209/209 [==============================] - 20s 98ms/step - loss: 0.0042 - mean_directional_accuracy: 0.9825 - val_loss: 0.0041 - val_mean_directional_accuracy: 0.6000
# Epoch 11/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0040 - mean_directional_accuracy: 0.9856 - val_loss: 0.0119 - val_mean_directional_accuracy: 0.5333
# Epoch 12/1000
# 209/209 [==============================] - 18s 84ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9872 - val_loss: 0.0055 - val_mean_directional_accuracy: 0.5333
# Epoch 13/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0041 - mean_directional_accuracy: 0.9841 - val_loss: 0.0163 - val_mean_directional_accuracy: 0.5333
# Epoch 14/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0048 - mean_directional_accuracy: 0.9841 - val_loss: 0.0042 - val_mean_directional_accuracy: 0.5667
# Epoch 15/1000
# 209/209 [==============================] - 18s 85ms/step - loss: 0.0039 - mean_directional_accuracy: 0.9777 - val_loss: 0.0051 - val_mean_directional_accuracy: 0.5333
# Epoch 16/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0040 - mean_directional_accuracy: 0.9856 - val_loss: 0.0114 - val_mean_directional_accuracy: 0.5333
# Epoch 17/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0041 - mean_directional_accuracy: 0.9721 - val_loss: 0.0137 - val_mean_directional_accuracy: 0.5000
# Epoch 18/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0041 - mean_directional_accuracy: 0.9745 - val_loss: 0.0065 - val_mean_directional_accuracy: 0.5000
# Epoch 19/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9888 - val_loss: 0.0102 - val_mean_directional_accuracy: 0.5333
# Epoch 20/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0041 - mean_directional_accuracy: 0.9825 - val_loss: 0.0247 - val_mean_directional_accuracy: 0.5000
# Epoch 21/1000
# 209/209 [==============================] - 18s 85ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9817 - val_loss: 0.0192 - val_mean_directional_accuracy: 0.5000
# Epoch 22/1000
# 209/209 [==============================] - 19s 89ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9896 - val_loss: 0.0055 - val_mean_directional_accuracy: 0.5000
# Epoch 23/1000
# 209/209 [==============================] - 19s 91ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9729 - val_loss: 0.0211 - val_mean_directional_accuracy: 0.5333
# Epoch 24/1000
# 209/209 [==============================] - 19s 91ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9809 - val_loss: 0.0066 - val_mean_directional_accuracy: 0.5667
# Epoch 25/1000
# 209/209 [==============================] - 18s 84ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9809 - val_loss: 0.0202 - val_mean_directional_accuracy: 0.5667
# Epoch 26/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9841 - val_loss: 0.0102 - val_mean_directional_accuracy: 0.6000
# Epoch 27/1000
# 209/209 [==============================] - 18s 84ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9681 - val_loss: 0.0275 - val_mean_directional_accuracy: 0.5667
# Epoch 28/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0051 - mean_directional_accuracy: 0.9761 - val_loss: 0.0058 - val_mean_directional_accuracy: 0.5667
# Epoch 29/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9697 - val_loss: 0.0054 - val_mean_directional_accuracy: 0.5333
# Epoch 30/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9833 - val_loss: 0.0134 - val_mean_directional_accuracy: 0.5667
# Epoch 31/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.0050 - mean_directional_accuracy: 0.9793 - val_loss: 0.0451 - val_mean_directional_accuracy: 0.5667
# Epoch 32/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9856 - val_loss: 0.0083 - val_mean_directional_accuracy: 0.5333
# Epoch 33/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9825 - val_loss: 0.0106 - val_mean_directional_accuracy: 0.5667
# Epoch 34/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9761 - val_loss: 0.0099 - val_mean_directional_accuracy: 0.6000
# Epoch 35/1000
# 209/209 [==============================] - 18s 85ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9825 - val_loss: 0.0322 - val_mean_directional_accuracy: 0.6333
# Epoch 36/1000
# 209/209 [==============================] - 19s 93ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9809 - val_loss: 0.0167 - val_mean_directional_accuracy: 0.6333
# Epoch 37/1000
# 209/209 [==============================] - 18s 87ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9841 - val_loss: 0.0108 - val_mean_directional_accuracy: 0.7333
# Epoch 38/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9809 - val_loss: 0.0052 - val_mean_directional_accuracy: 0.5667
# Epoch 39/1000
# 209/209 [==============================] - 17s 84ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9904 - val_loss: 0.0127 - val_mean_directional_accuracy: 0.6333
# Epoch 40/1000
# 209/209 [==============================] - 17s 84ms/step - loss: 0.0048 - mean_directional_accuracy: 0.9809 - val_loss: 0.0058 - val_mean_directional_accuracy: 0.6000
# Epoch 41/1000
# 209/209 [==============================] - 18s 84ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9721 - val_loss: 0.0057 - val_mean_directional_accuracy: 0.6667
# Epoch 42/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9841 - val_loss: 0.0060 - val_mean_directional_accuracy: 0.5667
# Epoch 43/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9793 - val_loss: 0.0088 - val_mean_directional_accuracy: 0.6333
# Epoch 44/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9745 - val_loss: 0.0092 - val_mean_directional_accuracy: 0.6000
# Epoch 45/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9777 - val_loss: 0.0103 - val_mean_directional_accuracy: 0.5667
# Epoch 46/1000
# 209/209 [==============================] - 18s 84ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9809 - val_loss: 0.0188 - val_mean_directional_accuracy: 0.6000
# Epoch 47/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9665 - val_loss: 0.0180 - val_mean_directional_accuracy: 0.6000
# Epoch 48/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9809 - val_loss: 0.0056 - val_mean_directional_accuracy: 0.5667
# Epoch 49/1000
# 209/209 [==============================] - 19s 90ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9841 - val_loss: 0.0074 - val_mean_directional_accuracy: 0.6333
# Epoch 50/1000
# 209/209 [==============================] - 19s 91ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9825 - val_loss: 0.0062 - val_mean_directional_accuracy: 0.6000
# Epoch 51/1000
# 209/209 [==============================] - 19s 92ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9825 - val_loss: 0.0130 - val_mean_directional_accuracy: 0.6000
# Epoch 52/1000
# 209/209 [==============================] - 18s 84ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9841 - val_loss: 0.0056 - val_mean_directional_accuracy: 0.5667
# Epoch 53/1000
# 209/209 [==============================] - 18s 86ms/step - loss: 0.0042 - mean_directional_accuracy: 0.9809 - val_loss: 0.0062 - val_mean_directional_accuracy: 0.5667
# Epoch 54/1000
# 209/209 [==============================] - 18s 86ms/step - loss: 0.0042 - mean_directional_accuracy: 0.9856 - val_loss: 0.0103 - val_mean_directional_accuracy: 0.6000
# Epoch 55/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9841 - val_loss: 0.0064 - val_mean_directional_accuracy: 0.5667
# Epoch 56/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9872 - val_loss: 0.0160 - val_mean_directional_accuracy: 0.6000
# Epoch 57/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9904 - val_loss: 0.0125 - val_mean_directional_accuracy: 0.6000
# Epoch 58/1000
# 209/209 [==============================] - 16s 79ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9825 - val_loss: 0.0126 - val_mean_directional_accuracy: 0.6000
# Epoch 59/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9689 - val_loss: 0.0062 - val_mean_directional_accuracy: 0.6000
# Epoch 60/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9793 - val_loss: 0.0201 - val_mean_directional_accuracy: 0.5333
# Epoch 1/1000
# 209/209 [==============================] - 26s 94ms/step - loss: 4.1418 - mean_directional_accuracy: 0.9617 - val_loss: 0.2153 - val_mean_directional_accuracy: 0.6000
# Epoch 2/1000
# 209/209 [==============================] - 19s 91ms/step - loss: 0.0887 - mean_directional_accuracy: 0.9856 - val_loss: 0.0353 - val_mean_directional_accuracy: 0.6333
# Epoch 3/1000
# 209/209 [==============================] - 18s 86ms/step - loss: 0.0199 - mean_directional_accuracy: 0.9713 - val_loss: 0.0132 - val_mean_directional_accuracy: 0.6333
# Epoch 4/1000
# 209/209 [==============================] - 18s 85ms/step - loss: 0.0086 - mean_directional_accuracy: 0.9697 - val_loss: 0.0078 - val_mean_directional_accuracy: 0.6333
# Epoch 5/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0059 - mean_directional_accuracy: 0.9697 - val_loss: 0.0113 - val_mean_directional_accuracy: 0.6000
# Epoch 6/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9841 - val_loss: 0.0079 - val_mean_directional_accuracy: 0.6333
# Epoch 7/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9729 - val_loss: 0.0047 - val_mean_directional_accuracy: 0.6333
# Epoch 8/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0042 - mean_directional_accuracy: 0.9825 - val_loss: 0.0060 - val_mean_directional_accuracy: 0.6000
# Epoch 9/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0040 - mean_directional_accuracy: 0.9761 - val_loss: 0.0118 - val_mean_directional_accuracy: 0.6000
# Epoch 10/1000
# 209/209 [==============================] - 17s 79ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9745 - val_loss: 0.0117 - val_mean_directional_accuracy: 0.5667
# Epoch 11/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.0042 - mean_directional_accuracy: 0.9769 - val_loss: 0.0044 - val_mean_directional_accuracy: 0.5667
# Epoch 12/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.0040 - mean_directional_accuracy: 0.9729 - val_loss: 0.0227 - val_mean_directional_accuracy: 0.5333
# Epoch 13/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.0040 - mean_directional_accuracy: 0.9777 - val_loss: 0.0044 - val_mean_directional_accuracy: 0.5333
# Epoch 14/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.0048 - mean_directional_accuracy: 0.9793 - val_loss: 0.0210 - val_mean_directional_accuracy: 0.5333
# Epoch 15/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9809 - val_loss: 0.0046 - val_mean_directional_accuracy: 0.5333
# Epoch 16/1000
# 209/209 [==============================] - 19s 90ms/step - loss: 0.0040 - mean_directional_accuracy: 0.9856 - val_loss: 0.0093 - val_mean_directional_accuracy: 0.5333
# Epoch 17/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9809 - val_loss: 0.0045 - val_mean_directional_accuracy: 0.5000
# Epoch 18/1000
# 209/209 [==============================] - 18s 88ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9809 - val_loss: 0.0077 - val_mean_directional_accuracy: 0.5000
# Epoch 19/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9793 - val_loss: 0.0218 - val_mean_directional_accuracy: 0.4667
# Epoch 20/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0051 - mean_directional_accuracy: 0.9809 - val_loss: 0.0071 - val_mean_directional_accuracy: 0.4667
# Epoch 21/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9809 - val_loss: 0.0056 - val_mean_directional_accuracy: 0.4667
# Epoch 22/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9777 - val_loss: 0.0243 - val_mean_directional_accuracy: 0.4667
# Epoch 23/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0049 - mean_directional_accuracy: 0.9856 - val_loss: 0.0071 - val_mean_directional_accuracy: 0.5333
# Epoch 24/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9809 - val_loss: 0.0049 - val_mean_directional_accuracy: 0.5333
# Epoch 25/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9809 - val_loss: 0.0162 - val_mean_directional_accuracy: 0.5000
# Epoch 26/1000
# 209/209 [==============================] - 17s 79ms/step - loss: 0.0048 - mean_directional_accuracy: 0.9729 - val_loss: 0.0222 - val_mean_directional_accuracy: 0.4667
# Epoch 27/1000
# 209/209 [==============================] - 17s 79ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9872 - val_loss: 0.0159 - val_mean_directional_accuracy: 0.5333
# Epoch 28/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9809 - val_loss: 0.0080 - val_mean_directional_accuracy: 0.5333
# Epoch 29/1000
# 209/209 [==============================] - 18s 86ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9817 - val_loss: 0.0254 - val_mean_directional_accuracy: 0.5000
# Epoch 30/1000
# 209/209 [==============================] - 19s 89ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9825 - val_loss: 0.0258 - val_mean_directional_accuracy: 0.6000
# Epoch 31/1000
# 209/209 [==============================] - 19s 89ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9729 - val_loss: 0.0084 - val_mean_directional_accuracy: 0.6667
# Epoch 32/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9777 - val_loss: 0.0200 - val_mean_directional_accuracy: 0.5000
# Epoch 33/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9888 - val_loss: 0.0105 - val_mean_directional_accuracy: 0.6333
# Epoch 34/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9745 - val_loss: 0.0059 - val_mean_directional_accuracy: 0.5000
# Epoch 35/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9737 - val_loss: 0.0166 - val_mean_directional_accuracy: 0.6000
# Epoch 36/1000
# 209/209 [==============================] - 16s 79ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9904 - val_loss: 0.0057 - val_mean_directional_accuracy: 0.5333
# Epoch 37/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9761 - val_loss: 0.0061 - val_mean_directional_accuracy: 0.5333
# Epoch 38/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9761 - val_loss: 0.0059 - val_mean_directional_accuracy: 0.5667
# Epoch 39/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9745 - val_loss: 0.0101 - val_mean_directional_accuracy: 0.5000
# Epoch 40/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.0049 - mean_directional_accuracy: 0.9841 - val_loss: 0.0092 - val_mean_directional_accuracy: 0.6667
# Epoch 41/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9841 - val_loss: 0.0130 - val_mean_directional_accuracy: 0.5667
# Epoch 42/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9856 - val_loss: 0.0078 - val_mean_directional_accuracy: 0.5667
# Epoch 43/1000
# 209/209 [==============================] - 18s 89ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9801 - val_loss: 0.0246 - val_mean_directional_accuracy: 0.5667
# Epoch 44/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9825 - val_loss: 0.0155 - val_mean_directional_accuracy: 0.6000
# Epoch 45/1000
# 209/209 [==============================] - 17s 84ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9888 - val_loss: 0.0065 - val_mean_directional_accuracy: 0.5667
# Epoch 46/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9713 - val_loss: 0.0071 - val_mean_directional_accuracy: 0.5667
# Epoch 47/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9793 - val_loss: 0.0058 - val_mean_directional_accuracy: 0.5667
# Epoch 48/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9856 - val_loss: 0.0151 - val_mean_directional_accuracy: 0.6333
# Epoch 49/1000
# 209/209 [==============================] - 16s 79ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9809 - val_loss: 0.0273 - val_mean_directional_accuracy: 0.6000
# Epoch 50/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9777 - val_loss: 0.0103 - val_mean_directional_accuracy: 0.6000
# Epoch 51/1000
# 209/209 [==============================] - 16s 79ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9745 - val_loss: 0.0076 - val_mean_directional_accuracy: 0.5667
# Epoch 52/1000
# 209/209 [==============================] - 16s 79ms/step - loss: 0.0042 - mean_directional_accuracy: 0.9856 - val_loss: 0.0057 - val_mean_directional_accuracy: 0.5667
# Epoch 53/1000
# 209/209 [==============================] - 16s 79ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9809 - val_loss: 0.0111 - val_mean_directional_accuracy: 0.5667
# Epoch 54/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9761 - val_loss: 0.0233 - val_mean_directional_accuracy: 0.6000
# Epoch 55/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0042 - mean_directional_accuracy: 0.9713 - val_loss: 0.0112 - val_mean_directional_accuracy: 0.5667
# Epoch 56/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0042 - mean_directional_accuracy: 0.9777 - val_loss: 0.0050 - val_mean_directional_accuracy: 0.6000
# Epoch 57/1000
# 209/209 [==============================] - 18s 85ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9793 - val_loss: 0.0066 - val_mean_directional_accuracy: 0.5667
# Epoch 58/1000
# 209/209 [==============================] - 18s 87ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9777 - val_loss: 0.0221 - val_mean_directional_accuracy: 0.6000
# Epoch 59/1000
# 209/209 [==============================] - 18s 86ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9825 - val_loss: 0.0072 - val_mean_directional_accuracy: 0.5667
# Epoch 60/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9825 - val_loss: 0.0144 - val_mean_directional_accuracy: 0.5667
# Epoch 61/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0041 - mean_directional_accuracy: 0.9809 - val_loss: 0.0056 - val_mean_directional_accuracy: 0.6333
# Epoch 1/1000
# 209/209 [==============================] - 25s 92ms/step - loss: 4.2054 - mean_directional_accuracy: 0.9490 - val_loss: 0.2473 - val_mean_directional_accuracy: 0.6000
# Epoch 2/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0950 - mean_directional_accuracy: 0.9745 - val_loss: 0.0363 - val_mean_directional_accuracy: 0.6000
# Epoch 3/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.0198 - mean_directional_accuracy: 0.9841 - val_loss: 0.0446 - val_mean_directional_accuracy: 0.6000
# Epoch 4/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.0086 - mean_directional_accuracy: 0.9745 - val_loss: 0.0107 - val_mean_directional_accuracy: 0.6333
# Epoch 5/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0054 - mean_directional_accuracy: 0.9777 - val_loss: 0.0052 - val_mean_directional_accuracy: 0.6000
# Epoch 6/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0052 - mean_directional_accuracy: 0.9825 - val_loss: 0.0063 - val_mean_directional_accuracy: 0.6667
# Epoch 7/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9761 - val_loss: 0.0246 - val_mean_directional_accuracy: 0.6667
# Epoch 8/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9729 - val_loss: 0.0148 - val_mean_directional_accuracy: 0.6667
# Epoch 9/1000
# 209/209 [==============================] - 17s 84ms/step - loss: 0.0041 - mean_directional_accuracy: 0.9825 - val_loss: 0.0056 - val_mean_directional_accuracy: 0.6333
# Epoch 10/1000
# 209/209 [==============================] - 18s 88ms/step - loss: 0.0042 - mean_directional_accuracy: 0.9585 - val_loss: 0.0116 - val_mean_directional_accuracy: 0.6000
# Epoch 11/1000
# 209/209 [==============================] - 18s 86ms/step - loss: 0.0048 - mean_directional_accuracy: 0.9745 - val_loss: 0.0178 - val_mean_directional_accuracy: 0.6000
# Epoch 12/1000
# 209/209 [==============================] - 18s 86ms/step - loss: 0.0040 - mean_directional_accuracy: 0.9825 - val_loss: 0.0061 - val_mean_directional_accuracy: 0.5667
# Epoch 13/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9705 - val_loss: 0.0299 - val_mean_directional_accuracy: 0.5333
# Epoch 14/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0051 - mean_directional_accuracy: 0.9777 - val_loss: 0.0172 - val_mean_directional_accuracy: 0.5333
# Epoch 15/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9777 - val_loss: 0.0067 - val_mean_directional_accuracy: 0.5333
# Epoch 16/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0049 - mean_directional_accuracy: 0.9761 - val_loss: 0.0046 - val_mean_directional_accuracy: 0.5333
# Epoch 17/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9856 - val_loss: 0.0234 - val_mean_directional_accuracy: 0.5333
# Epoch 18/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9793 - val_loss: 0.0171 - val_mean_directional_accuracy: 0.5333
# Epoch 19/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9777 - val_loss: 0.0153 - val_mean_directional_accuracy: 0.5000
# Epoch 20/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9689 - val_loss: 0.0301 - val_mean_directional_accuracy: 0.5000
# Epoch 21/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9721 - val_loss: 0.0090 - val_mean_directional_accuracy: 0.5000
# Epoch 22/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0048 - mean_directional_accuracy: 0.9761 - val_loss: 0.0316 - val_mean_directional_accuracy: 0.5000
# Epoch 23/1000
# 209/209 [==============================] - 19s 90ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9809 - val_loss: 0.0091 - val_mean_directional_accuracy: 0.5333
# Epoch 24/1000
# 209/209 [==============================] - 18s 85ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9769 - val_loss: 0.0099 - val_mean_directional_accuracy: 0.4667
# Epoch 25/1000
# 209/209 [==============================] - 19s 92ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9825 - val_loss: 0.0071 - val_mean_directional_accuracy: 0.5000
# Epoch 26/1000
# 209/209 [==============================] - 18s 84ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9729 - val_loss: 0.0080 - val_mean_directional_accuracy: 0.5000
# Epoch 27/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9904 - val_loss: 0.0056 - val_mean_directional_accuracy: 0.5333
# Epoch 28/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9729 - val_loss: 0.0077 - val_mean_directional_accuracy: 0.5000
# Epoch 29/1000
# 209/209 [==============================] - 17s 84ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9825 - val_loss: 0.0184 - val_mean_directional_accuracy: 0.5333
# Epoch 30/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0051 - mean_directional_accuracy: 0.9657 - val_loss: 0.0459 - val_mean_directional_accuracy: 0.5333
# Epoch 31/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.0048 - mean_directional_accuracy: 0.9856 - val_loss: 0.0129 - val_mean_directional_accuracy: 0.5333
# Epoch 32/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9833 - val_loss: 0.0088 - val_mean_directional_accuracy: 0.6000
# Epoch 33/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9793 - val_loss: 0.0083 - val_mean_directional_accuracy: 0.5000
# Epoch 34/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0050 - mean_directional_accuracy: 0.9856 - val_loss: 0.0185 - val_mean_directional_accuracy: 0.6667
# Epoch 35/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9841 - val_loss: 0.0054 - val_mean_directional_accuracy: 0.5000
# Epoch 36/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9841 - val_loss: 0.0236 - val_mean_directional_accuracy: 0.5333
# Epoch 37/1000
# 209/209 [==============================] - 18s 84ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9825 - val_loss: 0.0130 - val_mean_directional_accuracy: 0.5333
# Epoch 38/1000
# 209/209 [==============================] - 18s 88ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9825 - val_loss: 0.0056 - val_mean_directional_accuracy: 0.4667
# Epoch 39/1000
# 209/209 [==============================] - 19s 90ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9904 - val_loss: 0.0074 - val_mean_directional_accuracy: 0.5000
# Epoch 40/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9809 - val_loss: 0.1312 - val_mean_directional_accuracy: 0.5667
# Epoch 41/1000
# 209/209 [==============================] - 17s 84ms/step - loss: 0.0062 - mean_directional_accuracy: 0.9841 - val_loss: 0.0104 - val_mean_directional_accuracy: 0.6000
# Epoch 42/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9856 - val_loss: 0.0056 - val_mean_directional_accuracy: 0.5333
# Epoch 43/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9872 - val_loss: 0.0075 - val_mean_directional_accuracy: 0.6667
# Epoch 44/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9888 - val_loss: 0.0076 - val_mean_directional_accuracy: 0.5667
# Epoch 45/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9856 - val_loss: 0.0058 - val_mean_directional_accuracy: 0.5333
# Epoch 46/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9841 - val_loss: 0.0191 - val_mean_directional_accuracy: 0.5667
# Epoch 47/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9809 - val_loss: 0.0069 - val_mean_directional_accuracy: 0.5667
# Epoch 48/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9856 - val_loss: 0.0055 - val_mean_directional_accuracy: 0.5667
# Epoch 49/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0049 - mean_directional_accuracy: 0.9888 - val_loss: 0.0063 - val_mean_directional_accuracy: 0.6000
# Epoch 50/1000
# 209/209 [==============================] - 18s 84ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9745 - val_loss: 0.0065 - val_mean_directional_accuracy: 0.5667
# Epoch 51/1000
# 209/209 [==============================] - 18s 88ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9761 - val_loss: 0.0241 - val_mean_directional_accuracy: 0.5333
# Epoch 52/1000
# 209/209 [==============================] - 18s 87ms/step - loss: 0.0048 - mean_directional_accuracy: 0.9856 - val_loss: 0.0055 - val_mean_directional_accuracy: 0.6000
# Epoch 53/1000
# 209/209 [==============================] - 18s 84ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9793 - val_loss: 0.0157 - val_mean_directional_accuracy: 0.6667
# Epoch 54/1000
# 209/209 [==============================] - 18s 86ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9904 - val_loss: 0.0134 - val_mean_directional_accuracy: 0.6667
# Epoch 55/1000
# 209/209 [==============================] - 18s 86ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9761 - val_loss: 0.0176 - val_mean_directional_accuracy: 0.6000
# Epoch 56/1000
# 209/209 [==============================] - 18s 84ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9697 - val_loss: 0.0159 - val_mean_directional_accuracy: 0.5667
# Epoch 57/1000
# 209/209 [==============================] - 18s 84ms/step - loss: 0.0043 - mean_directional_accuracy: 0.
1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0039 - mean_directional_accuracy: 0.9793 - val_loss: 0.0057 - val_mean_directional_accuracy: 0.5333
# Epoch 18/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9825 - val_loss: 0.0052 - val_mean_directional_accuracy: 0.5000
# Epoch 19/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9841 - val_loss: 0.0074 - val_mean_directional_accuracy: 0.5333
# Epoch 20/1000
# 209/209 [==============================] - 17s 84ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9761 - val_loss: 0.0125 - val_mean_directional_accuracy: 0.4667
# Epoch 21/1000
# 209/209 [==============================] - 17s 84ms/step - loss: 0.0041 - mean_directional_accuracy: 0.9809 - val_loss: 0.0070 - val_mean_directional_accuracy: 0.5333
# Epoch 22/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9825 - val_loss: 0.0079 - val_mean_directional_accuracy: 0.5333
# Epoch 23/1000
# 209/209 [==============================] - 18s 84ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9825 - val_loss: 0.0059 - val_mean_directional_accuracy: 0.5333
# Epoch 24/1000
# 209/209 [==============================] - 19s 90ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9825 - val_loss: 0.0184 - val_mean_directional_accuracy: 0.5667
# Epoch 25/1000
# 209/209 [==============================] - 18s 87ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9793 - val_loss: 0.0078 - val_mean_directional_accuracy: 0.5333
# Epoch 26/1000
# 209/209 [==============================] - 20s 96ms/step - loss: 0.0049 - mean_directional_accuracy: 0.9777 - val_loss: 0.0050 - val_mean_directional_accuracy: 0.5667
# Epoch 27/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9809 - val_loss: 0.0106 - val_mean_directional_accuracy: 0.6333
# Epoch 28/1000
# 209/209 [==============================] - 18s 84ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9745 - val_loss: 0.0059 - val_mean_directional_accuracy: 0.5000
# Epoch 29/1000
# 209/209 [==============================] - 18s 84ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9793 - val_loss: 0.0055 - val_mean_directional_accuracy: 0.6000
# Epoch 30/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9761 - val_loss: 0.0122 - val_mean_directional_accuracy: 0.6000
# Epoch 31/1000
# 209/209 [==============================] - 17s 84ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9825 - val_loss: 0.0066 - val_mean_directional_accuracy: 0.6000
# Epoch 32/1000
# 209/209 [==============================] - 18s 86ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9777 - val_loss: 0.0167 - val_mean_directional_accuracy: 0.5667
# Epoch 33/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9777 - val_loss: 0.0141 - val_mean_directional_accuracy: 0.5333
# Epoch 34/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0050 - mean_directional_accuracy: 0.9888 - val_loss: 0.0091 - val_mean_directional_accuracy: 0.6000
# Epoch 35/1000
# 209/209 [==============================] - 18s 85ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9841 - val_loss: 0.0262 - val_mean_directional_accuracy: 0.5000
# Epoch 36/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9713 - val_loss: 0.0170 - val_mean_directional_accuracy: 0.6000
# Epoch 37/1000
# 209/209 [==============================] - 18s 87ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9761 - val_loss: 0.0072 - val_mean_directional_accuracy: 0.6333
# Epoch 38/1000
# 209/209 [==============================] - 18s 88ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9825 - val_loss: 0.0089 - val_mean_directional_accuracy: 0.5667
# Epoch 39/1000
# 209/209 [==============================] - 18s 87ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9761 - val_loss: 0.0096 - val_mean_directional_accuracy: 0.5000
# Epoch 40/1000
# 209/209 [==============================] - 18s 88ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9841 - val_loss: 0.0094 - val_mean_directional_accuracy: 0.4667
# Epoch 41/1000
# 209/209 [==============================] - 18s 88ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9841 - val_loss: 0.0062 - val_mean_directional_accuracy: 0.5667
# Epoch 42/1000
# 209/209 [==============================] - 18s 87ms/step - loss: 0.0057 - mean_directional_accuracy: 0.9777 - val_loss: 0.0058 - val_mean_directional_accuracy: 0.6000
# Epoch 43/1000
# 209/209 [==============================] - 18s 84ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9888 - val_loss: 0.0183 - val_mean_directional_accuracy: 0.5667
# Epoch 44/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9825 - val_loss: 0.0269 - val_mean_directional_accuracy: 0.5667
# Epoch 45/1000
# 209/209 [==============================] - 18s 84ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9785 - val_loss: 0.0324 - val_mean_directional_accuracy: 0.6000
# Epoch 46/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9745 - val_loss: 0.0074 - val_mean_directional_accuracy: 0.5667
# Epoch 47/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9825 - val_loss: 0.0066 - val_mean_directional_accuracy: 0.5667
# Epoch 48/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9841 - val_loss: 0.0077 - val_mean_directional_accuracy: 0.5667
# Epoch 49/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9777 - val_loss: 0.0057 - val_mean_directional_accuracy: 0.6000
# Epoch 50/1000
# 209/209 [==============================] - 18s 87ms/step - loss: 0.0044 - mean_directional_accuracy: 0.
# Epoch 3/1000
# 209/209 [==============================] - 20s 95ms/step - loss: 0.0106 - mean_directional_accuracy: 0.9841 - val_loss: 0.0179 - val_mean_directional_accuracy: 0.6667
# Epoch 4/1000
# 209/209 [==============================] - 20s 95ms/step - loss: 0.0066 - mean_directional_accuracy: 0.9729 - val_loss: 0.0158 - val_mean_directional_accuracy: 0.6667
# Epoch 5/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9745 - val_loss: 0.0170 - val_mean_directional_accuracy: 0.6333
# Epoch 6/1000
# 209/209 [==============================] - 17s 84ms/step - loss: 0.0047 - mean_directional_accuracy: 0.9777 - val_loss: 0.0067 - val_mean_directional_accuracy: 0.6000
# Epoch 7/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9825 - val_loss: 0.0098 - val_mean_directional_accuracy: 0.6000
# Epoch 8/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0042 - mean_directional_accuracy: 0.9745 - val_loss: 0.0121 - val_mean_directional_accuracy: 0.5667
# Epoch 9/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9761 - val_loss: 0.0053 - val_mean_directional_accuracy: 0.5667
# Epoch 10/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0041 - mean_directional_accuracy: 0.9833 - val_loss: 0.0320 - val_mean_directional_accuracy: 0.5667
# Epoch 11/1000
# 209/209 [==============================] - 18s 85ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9777 - val_loss: 0.0048 - val_mean_directional_accuracy: 0.5667
# Epoch 12/1000
# 209/209 [==============================] - 19s 92ms/step - loss: 0.0039 - mean_directional_accuracy: 0.9697 - val_loss: 0.0049 - val_mean_directional_accuracy: 0.5667
# Epoch 13/1000
# 209/209 [==============================] - 18s 86ms/step - loss: 0.0039 - mean_directional_accuracy: 0.9705 - val_loss: 0.0085 - val_mean_directional_accuracy: 0.5333
# Epoch 14/1000
# 209/209 [==============================] - 18s 88ms/step - loss: 0.0041 - mean_directional_accuracy: 0.9745 - val_loss: 0.0121 - val_mean_directional_accuracy: 0.5333
# Epoch 15/1000
# 209/209 [==============================] - 20s 95ms/step - loss: 0.0042 - mean_directional_accuracy: 0.9745 - val_loss: 0.0132 - val_mean_directional_accuracy: 0.5333
# Epoch 16/1000
# 209/209 [==============================] - 19s 92ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9793 - val_loss: 0.0089 - val_mean_directional_accuracy: 0.5000
# Epoch 17/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9856 - val_loss: 0.0070 - val_mean_directional_accuracy: 0.4667
# Epoch 18/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0042 - mean_directional_accuracy: 0.9713 - val_loss: 0.0062 - val_mean_directional_accuracy: 0.4667
# Epoch 19/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0050 - mean_directional_accuracy: 0.9729 - val_loss: 0.0094 - val_mean_directional_accuracy: 0.4667
# Epoch 20/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0041 - mean_directional_accuracy: 0.9856 - val_loss: 0.0081 - val_mean_directional_accuracy: 0.5000
# Epoch 21/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9825 - val_loss: 0.0070 - val_mean_directional_accuracy: 0.4667
# Epoch 22/1000
# 209/209 [==============================] - 18s 84ms/step - loss: 0.0045 - mean_directional_accuracy: 0.9841 - val_loss: 0.0053 - val_mean_directional_accuracy: 0.5333
# Epoch 23/1000
# 209/209 [==============================] - 18s 85ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9761 - val_loss: 0.0083 - val_mean_directional_accuracy: 0.5333
# Epoch 24/1000
# 209/209 [==============================] - 18s 86ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9729 - val_loss: 0.0269 - val_mean_directional_accuracy: 0.5333
# Epoch 25/1000
# 209/209 [==============================] - 17s 81ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9777 - val_loss: 0.0123 - val_mean_directional_accuracy: 0.5667
# Epoch 26/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0050 - mean_directional_accuracy: 0.9793 - val_loss: 0.0107 - val_mean_directional_accuracy: 0.4667
# Epoch 27/1000
# 209/209 [==============================] - 17s 80ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9761 - val_loss: 0.0070 - val_mean_directional_accuracy: 0.5000
# Epoch 28/1000
# 209/209 [==============================] - 17s 84ms/step - loss: 0.0044 - mean_directional_accuracy: 0.9793 - val_loss: 0.0052 - val_mean_directional_accuracy: 0.5000
# Epoch 29/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0043 - mean_directional_accuracy: 0.9841 - val_loss: 0.0079 - val_mean_directional_accuracy: 0.5333
# Epoch 30/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0046 - mean_directional_accuracy: 0.9872 - val_loss: 0.0066 - val_mean_directional_accuracy: 0.5000
# Epoch 31/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.
ms/step - loss: 0.0042 - mean_directional_accuracy: 0.9777 - val_loss: 0.0070 - val_mean_directional_accuracy: 0.5000
# Epoch 58/1000
# 209/209 [==============================] - 18s 86ms/step - loss: 0.0040 - mean_directional_accuracy: 0.9729 - val_loss: 0.0130 - val_mean_directional_accuracy: 0.4667
# Epoch 59/1000
# 209/209 [==============================] - 17s 83ms/step - loss: 0.0039 - mean_directional_accuracy: 0.9825 - val_loss: 0.0134 - val_mean_directional_accuracy: 0.5333
# Epoch 60/1000
# 209/209 [==============================] - 18s 86ms/step - loss: 0.0042 - mean_directional_accuracy: 0.9761 - val_loss: 0.0094 - val_mean_directional_accuracy: 0.4333
# Epoch 61/1000
# 209/209 [==============================] - 17s 82ms/step - loss: 0.0039 - mean_directional_accuracy: 0.9665 - val_loss: 0.0127 - val_mean_directional_accuracy: 0.5000

# %% [markdown]
# #### Utiliser la médiane des prédictions

# %%
median_predictions = np.median(np.array(all_predictions), axis=0)

# %%
#Appliquer le filtre gaussien aux données réelles
smoothed_real_values = gaussian_filter1d(real_values, sigma=5)

# %%
plt.figure(figsize=(14, 7))

for predictions in all_predictions:
    
    predictions_close = predictions[:, 0]
    predictions_close_inverse = sp500_scaler.inverse_transform(predictions_close)
    plt.plot(predictions_close_inverse[:, 0], label='Model Predictions', linestyle='--')

# Inverser la mise à l'échelle des valeurs réelles (y_test_final)
inverse_real_values = sp500_scaler.inverse_transform(y_test_final.reshape(-1, 1))

# Extraire les valeurs de clôture
inverse_real_values_close = inverse_real_values[:, 0]
plt.plot(inverse_real_values_close, label='Real Values')
plt.legend()

plt.title('Scaled Predictions from Top 5 Models')

plt.show()

# %% [markdown]
# #### Graphique comparatif avec les valeurs réelles

# %%
inverse_final_predictions = sp500_scaler.inverse_transform(median_predictions[:,0])
print(inverse_final_predictions.shape)
# Out:
# (90, 1)

# %%
# Afficher les dernières valeurs réelles pour chaque feature (y compris le SP500)
print("Dernières valeurs réelles :")
for feature in final_features:
    real_value = combined_data[feature].iloc[-1-len(y_test)]
    print(f"{feature}: {real_value}")

real_sp500 = combined_data[('GSPC', 'Close')].iloc[-1-len(y_test)]
print(f"GSPC_Close: {real_sp500}")

print("\nPremières valeurs prédites :")
# Afficher les premières valeurs prédites pour chaque feature
for feature in final_features:
    model_type = best_model_per_feature['Best Model'][feature]
    predicted_feature_value = all_recursive_preds[model_type][feature][0]
    # Inversez la mise à l'échelle pour la caractéristique prédite
    print(f"{feature}: {predicted_feature_value}")

# Afficher la première valeur prédite pour le SP500
predicted_sp500_value = median_predictions[0]
inverse_sp500_prediction = sp500_scaler.inverse_transform(np.array(predicted_sp500_value).reshape(-1, 1))
print(f"GSPC_Close : {inverse_sp500_prediction[0][0]}")
# Out:
# Dernières valeurs réelles :
# ('NG_F', 'Close'): 2.3959999084472656
# ('NVDA', 'Close'): 222.0500030517578
# GSPC_Close: 4117.85986328125
#
# Premières valeurs prédites :
# ('NG_F', 'Close'): [2.612946]
# ('NVDA', 'Close'): 181.13963317871094
# GSPC_Close : 4414.13232421875

# %%
inverse_final_predictions_close = inverse_final_predictions[:, 0]
# Utilisez le scaler pour inverser la mise à l'échelle des dernières valeurs réelles de l'ensemble d'entraînement pour le S&P 500
last_real_values_train_scaled = y_train_final
last_real_values_train = sp500_scaler.inverse_transform(last_real_values_train_scaled.reshape(-1, 1))[:, 0]  # On prend seulement les valeurs de clôture

# Inverser la mise à l'échelle des valeurs réelles (y_test_final)
inverse_real_values = sp500_scaler.inverse_transform(y_test_final.reshape(-1, 1))

# Extraire les valeurs de clôture
inverse_real_values_close = inverse_real_values[:, 0]

# Concaténer les dernières valeurs réelles de l'ensemble d'entraînement avec les vraies valeurs de l'ensemble de test
real_values = np.concatenate([last_real_values_train, inverse_real_values_close])


#inverse_final_predictions_close = inverse_final_predictions_close -(inverse_final_predictions_close[0] - last_real_values_train[-1])

# Concaténer les dernières valeurs réelles de l'ensemble d'entraînement avec les valeurs prédites
predicted_values = np.concatenate([last_real_values_train, inverse_final_predictions_close])

inverse_final_predictions_close = inverse_final_predictions_close -(inverse_final_predictions_close[0] - last_real_values_train[-1])
plt.figure(figsize=(14,7))

# Tracer les valeurs réelles
plt.plot(real_values[-150 - (len(real_values) - len(predicted_values)):], label='Real Close Values', color='blue')
# Tracer les valeurs prédites
plt.plot(predicted_values[-150:], label='Predicted Close Values', color='red', linestyle='--')

plt.title("Final LSTM Model - Predictions vs Real Close Values for S&P 500 (Training and Test Data)")
plt.legend()
plt.show()

inverse_final_predictions_close
# Out:
# array([3765.9492, 3743.0264, 3724.7705, 3690.6514, 3672.4946, 3661.4941,
#        3652.5957, 3643.2808, 3626.9937, 3609.0327, 3592.623 , 3577.6792,
#        3563.815 , 3551.0918, 3539.4297, 3528.316 , 3517.7812, 3508.0205,
#        3498.9644, 3491.0137, 3483.9785, 3477.7998, 3472.5557, 3467.9927,
#        3464.0347, 3460.7866, 3458.4238, 3456.5762, 3455.3828, 3454.5771,
#        3454.6543, 3455.1338, 3456.0571, 3457.7314, 3460.1987, 3463.373 ,
#        3467.3325, 3471.418 , 3476.2388, 3481.4844, 3486.9146, 3489.0776,
#        3490.9385, 3494.105 , 3496.7441, 3500.4702, 3503.8364, 3508.3267,
#        3512.2583, 3517.2402, 3521.518 , 3526.8164, 3531.774 , 3537.5732,
#        3542.9922, 3549.2817, 3555.1333, 3561.4678, 3567.3872, 3573.896 ,
#        3580.1519, 3586.978 , 3593.3584, 3600.2002, 3606.3833, 3613.1514,
#        3619.3057, 3625.3516, 3630.7334, 3636.6719, 3642.3374, 3647.8203,
#        3652.7964, 3657.7456, 3662.5322, 3666.8955, 3670.8457, 3674.999 ,
#        3679.2915, 3683.6523, 3687.6514, 3691.5732, 3695.1143, 3698.4604,
#        3701.4883, 3704.4941, 3707.4097, 3710.5063, 3713.5503, 3716.2754],
#       dtype=float32)

# %% [markdown]
# #### Prédiction futures:

# %%
#other features
other_features_pred = []
for feature in final_features:
    model_type = best_model_per_feature['Best Model'][feature]
    if model_type == "GRU":
        model = gru_models[feature]
        initial_input = scaled_data_df[[feature]][-look_back:]
        predictions = recursive_prediction_multi_output(model, initial_input, 30)
        feature_scaler = scalers_dict[feature]
        predictions = feature_scaler.inverse_transform(np.array(predictions).reshape(-1, 1))
        other_features_pred.append(predictions)
        
        plt.figure(figsize=(14,7))
        plt.plot(predictions, label=f'Prediction Close Values for {feature}', color='red')
        plt.title(f"Final LSTM Model - Predictions Close Values for {feature} (Future)")
        plt.legend()
        plt.show()
# Out:
# 1/1 [==============================] - 0s 337ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 111ms/step

# %% [markdown]
# #### Métriques d'évaluation:

# %%
# Métriques d'évaluation
min_length = min(len(inverse_real_values_close), len(inverse_final_predictions_close))
mse = mean_squared_error(inverse_real_values_close[:min_length], inverse_final_predictions_close[:min_length])
rmse = np.sqrt(mse)
mae = mean_absolute_error(inverse_real_values_close[:min_length], inverse_final_predictions_close[:min_length])
r2 = r2_score(inverse_real_values_close[:min_length], inverse_final_predictions_close[:min_length])

print(f"Erreur quadratique moyenne MSE: {mse}")
print(f"Racine de l'erreur quadratique moyenne RMSE: {rmse}")
print(f"Erreur absolue moyenne MAE: {mae}")
print(f"Coefficient de détermination R²: {r2}")
# Out:
# Erreur quadratique moyenne MSE: 172560.23198059708
# Racine de l'erreur quadratique moyenne RMSE: 415.40369760101686
# Erreur absolue moyenne MAE: 405.4491144042483
# Coefficient de détermination R²: -14.077237444411457

# %%
# Calculer la direction réelle des changements de prix
real_direction = np.sign(np.diff(inverse_real_values_close[:min_length]))

# Calculer la direction prédite des changements de prix
predicted_direction = np.sign(np.diff(inverse_final_predictions_close[:min_length]))

# Créer une matrice de confusion
conf_matrix = confusion_matrix(real_direction, predicted_direction, labels=[1, -1])

print("Matrice de confusion:")
print(conf_matrix)
# Out:
# Matrice de confusion:
# [[28 10]
#  [32 19]]

# %% [markdown]
# # Simulation Gain/Perte

# %%
def simulate_trading_strategy(predictions, actual_prices, min_yield=0.000117, stop_loss=0.05, 
                              take_profit=0.05, transaction_fee=0.001, anticipation_days=2, delay_days=2):
    capital = 150
    realized_gain = [0]  # Gain that is realized by selling
    stock_quantity = 0  # Number of stocks owned
    capital_over_time = [capital]  # Track capital over time
    realized_gain_over_time = [realized_gain]  # Track realized gain over time

    last_price = actual_prices[0]

    for i in range(1, len(predictions)):

        if i % 5 != 0:
            continue

        start_window = max(0, i - anticipation_days)
        end_window = min(len(predictions) - 1, i + delay_days)
        
        window_predictions = predictions[start_window:end_window + 1]
        window_actuals = actual_prices[start_window:end_window + 1]
        
        mean_prediction = np.mean(window_predictions)
        mean_actual = np.mean(window_actuals)

        pred_today = mean_prediction
        pred_yesterday = predictions[i - 5]
        actual_today = mean_actual
        actual_yesterday = actual_prices[i - 5]
        
        expected_return = (pred_today - pred_yesterday) / pred_yesterday
        actual_return = (actual_today - actual_yesterday) / actual_yesterday

        if expected_return > min_yield and actual_return > min_yield:
            confidence_factor = 1.2
        else:
            confidence_factor = 1.0

        dynamic_stop_loss = stop_loss * confidence_factor
        dynamic_take_profit = take_profit * confidence_factor

        if stock_quantity > 0:
            gain_loss = (actual_today - last_price) / last_price

            if gain_loss >= dynamic_take_profit:
                capital += stock_quantity * actual_today * (1 - transaction_fee)
                realized_gain += stock_quantity * (actual_today - last_price)
                stock_quantity = 0

            elif gain_loss <= -dynamic_stop_loss:
                capital += stock_quantity * actual_today * (1 - transaction_fee)
                realized_gain += stock_quantity * (actual_today - last_price)
                stock_quantity = 0

        if expected_return > min_yield and capital > 0:
            buy_quantity = capital / actual_today
            capital -= buy_quantity * actual_today
            stock_quantity += buy_quantity
            last_price = actual_today

            print(f"Buy executed on day {i}. New stock quantity : {stock_quantity}")
            
        if expected_return < -min_yield and stock_quantity > 0:
            sell_quantity = stock_quantity  # sell all stocks
            capital += sell_quantity * actual_today  # Add to capital
            stock_quantity = 0  # Reset stock quantity
            last_price = actual_today  # Update the last price when a stock is sold
            print(f"Sell executed on day {i}. New stock quantity : 0")

        total_capital = capital + stock_quantity * actual_today
        capital_over_time.append(total_capital)
        realized_gain_over_time.append(realized_gain[0])

    strategy_returns = np.diff(np.array(capital_over_time)) / np.array(capital_over_time)[:-1]
    return strategy_returns, capital_over_time, realized_gain_over_time

strategy_returns, capital_over_time, realized_gain_over_time = simulate_trading_strategy(inverse_final_predictions_close, inverse_real_values)
realized_gain_over_time[0] = 0
# Out:
# Buy executed on day 35. New stock quantity : 0.038936792001711296
# Buy executed on day 60. New stock quantity : 0.038897855209709585

# %%
# Generate some sample data for the sake of demonstration
days = list(range(len(capital_over_time)))

# Plotting the evolution of capital over time
plt.figure(figsize=(12, 6))
plt.plot(days, capital_over_time, label="Capital Over Time", color='blue')
plt.xlabel("Weeks")
plt.ylabel("Capital")
plt.title("Evolution of Capital Over Time")
plt.legend()
plt.grid(True)
plt.show()

# Plotting the evolution of realized gain over time
plt.figure(figsize=(12, 6))
plt.plot(days, realized_gain_over_time, label="Realized Gain Over Time", color='green')
plt.xlabel("Weeks")
plt.ylabel("Realized Gain")
plt.title("Evolution of Realized Gain Over Time")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate the absolute and percentage gain/loss

initial_capital = capital_over_time[0]

final_capital = capital_over_time[-1]



absolute_gain_loss = final_capital - initial_capital

percentage_gain_loss = ((final_capital - initial_capital) / initial_capital) * 100



# Calculate volatility as the standard deviation of the returns

returns = np.diff(np.array(capital_over_time)) / np.array(capital_over_time)[:-1]

volatility = np.std(returns)

print(f"Gain/perte absolu sur {len(capital_over_time)*5 -1} jours : {absolute_gain_loss}")
print(f"Gain/perte en % sur {len(capital_over_time)*5 -1} jours : {percentage_gain_loss}")
print(f"Volatilité de l'indice sur {len(capital_over_time)*5 -1} jours : {volatility}")

annualized_return_percentage = ((1 + percentage_gain_loss/100) ** (252 / len(capital_over_time)/5 -1) - 1) * 100

print(f"Taux gain/perte annualisé : {annualized_return_percentage}")

initial_market_price = inverse_real_values_close[0]
final_market_price = inverse_real_values_close[len(capital_over_time)*5 -1]
market_return = (final_market_price - initial_market_price) / initial_market_price * 100

# Calculate if we beat the market
beat_the_market = percentage_gain_loss > market_return

print(f"Rendement du marché en % sur {len(capital_over_time)*5 - 1} jours : {market_return}")
print(f"Est-ce que nous avons battu le marché ? {'Oui' if beat_the_market else 'Non'} : {market_return:.2f} % {'<' if beat_the_market else '>'} {percentage_gain_loss:.2f} %")
# Out:
# Gain/perte absolu sur 89 jours : 4.828689827699321
# Gain/perte en % sur 89 jours : 3.2191265517995475
# Volatilité de l'indice sur 89 jours : 0.0141736680898511
# Taux gain/perte annualisé : 5.8688811799107565
# Rendement du marché en % sur 89 jours : -0.8300781767260488
# Est-ce que nous avons battu le marché ? Oui : -0.83 % < 3.22 %

# %%
# Calcul du ratio de Sharpe
mean_return = np.mean(np.diff(inverse_real_values_close) / inverse_real_values_close[:-1])
sharpe_ratio = mean_return / np.std(np.diff(inverse_real_values_close) / inverse_real_values_close[:-1])

print(f"Ratio de Sharpe: {sharpe_ratio}")
# Out:
# Ratio de Sharpe: 0.04216532177397232

# %% [markdown]
# ## Conclusion

# %%
def calculate_directional_accuracy(real_values, predicted_values):
    correct_directions = 0
    total_directions = 0
    
    #fenêtre glissante sur 10 jours (2 semaines, du lundi au vendredi)
    for i in range(0, len(predicted_values), 5): #first cycle of 5 never used
        real_diff = real_values[i] - real_values[i-5]
        predicted_diff = predicted_values[i] - predicted_values[i-5]

        if (real_diff > 0 and predicted_diff > 0) or (real_diff < 0 and predicted_diff < 0):
            correct_directions += 1
        else: 
            print(f"Variation entre n°{i} et n°{i+5} fausse")

        total_directions += 1

    directional_accuracy = (correct_directions / total_directions) * 100
    return directional_accuracy

directional_accuracy = calculate_directional_accuracy(inverse_real_values_close, inverse_final_predictions_close)
print(f"Précision directionnelle sur 1 semaine: {directional_accuracy:.2f}%")
# Out:
# Variation entre n°0 et n°5 fausse
# Variation entre n°10 et n°15 fausse
# Variation entre n°30 et n°35 fausse
# Variation entre n°35 et n°40 fausse
# Variation entre n°50 et n°55 fausse
# Variation entre n°65 et n°70 fausse
# Variation entre n°70 et n°75 fausse
# Variation entre n°80 et n°85 fausse
# Variation entre n°85 et n°90 fausse
# Précision directionnelle sur 1 semaine: 50.00%

# %% [markdown]
# Les résultats sont très encourageants, un investissement naïf au jour 0 aurait conduit à une perte de capital.
#
# Les prédictions semblent très satisfaisantes dans la mesure où nous battons le marché sur cette période et ce, avec un taux de gain bien superieur au marché
#
# Quelques points et améliorations cependant à soulever :
#
# - Les prédictions des features autres que la valeur de l'indice lui-même ne sont disponibles que pour la valeur de clôture (et pas d'ouverture, pour l'ouverture on utilise donc la dernière valeur connue), la précision pour les modèles des features ainsi que le modèle final peut donc être encore augmenté.
#
#
# - Toute la partie sur la simulation de gain/perte suppose que ce notebook n'est jamais réexécuté pendant 94 jours (valeur du look back), or, dans les faits, prédire à nouveau la valeur de l'indice avec les nouvelles valeurs réelles augmentera les chances de corriger les prédictions directionnelles fausses à plus long terme.
#
#
# - Les performances passées ne préjugent pas des performances futures, c'est valable pour un fonds investi en actions tout comme les performances de ce notebook, prenez du recul sur les résultats produits par ce dernier s'il a une quelconque influence sur vos investissements.
